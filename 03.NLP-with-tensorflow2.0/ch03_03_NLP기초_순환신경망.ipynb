# %% [markdown]
# <a href="https://colab.research.google.com/github/pthkbs123/SkillTreePython-DeepLearning/blob/main/03.NLP-with-tensorflow2.0/ch03_03_NLP%EA%B8%B0%EC%B4%88_%EC%88%9C%ED%99%98%EC%8B%A0%EA%B2%BD%EB%A7%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ch03.03 NLP기초 - 순환 신경망
# ---
#
# * 날짜:
# * 이름:
#
#
# ## 학습내용
#     - 순환 신경망에 대해 이해한다.
#     - RNN
#     - GRU
#     - LSTM

# %% [markdown]
# ```
# ! git clone https://github.com/yebiny/SkillTreePython-DeepLearning
# ```

# %%
! git clone https://github.com/yebiny/SkillTreePython-DeepLearning
# Out:
# Cloning into 'SkillTreePython-DeepLearning'...
# remote: Enumerating objects: 735, done.
# remote: Counting objects: 100% (308/308), done.
# remote: Compressing objects: 100% (152/152), done.
# remote: Total 735 (delta 187), reused 255 (delta 155), pack-reused 427
# Receiving objects: 100% (735/735), 38.42 MiB | 27.49 MiB/s, done.
# Resolving deltas: 100% (380/380), done.

# %% [markdown]
# ```
# import sys
# sys.path.append('/content/SkillTreePython-DeepLearning/scripts')
# from import_lib import *
# from plot_result import *
# ```

# %%
import sys
sys.path.append('/content/SkillTreePython-DeepLearning/scripts')
from import_lib import *
from plot_result import *

# %% [markdown]
# ## imdb 베이스 모델
# ---

# %% [markdown]
# ### **| imdb 데이터 처리**
# ```
# MAX_LEN = 256
# MAX_FEATURES = 10000
#
# imdb = tf.keras.datasets.imdb
# (x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=MAX_FEATURES)
# x_train = preprocessing.sequence.pad_sequences(x_train,
#                                                padding='post',
#                                                maxlen=MAX_LEN)
#
# x_test = preprocessing.sequence.pad_sequences(x_test,
#                                               padding='post',
#                                               maxlen=MAX_LEN)
# print(x_train.shape, x_test.shape)
# ```

# %%
MAX_LEN = 256
MAX_FEATURES = 10000

imdb = tf.keras.datasets.imdb
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=MAX_FEATURES)
x_train = preprocessing.sequence.pad_sequences(x_train,
                                               padding='post',
                                               maxlen=MAX_LEN)

x_test = preprocessing.sequence.pad_sequences(x_test,
                                              padding='post',
                                              maxlen=MAX_LEN)
print(x_train.shape, x_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# 17473536/17464789 [==============================] - 0s 0us/step
# (25000, 256) (25000, 256)

# %% [markdown]
# ### **| FCN with GlobalAveragePooling1D**

# %%
EMB_DIMS = 32
x = layers.Input(shape = MAX_LEN)
y = layers.Embedding(MAX_FEATURES, EMB_DIMS )(x)
y = layers.GlobalAveragePooling1D()(y)
y = layers.Dense(1, activation = 'sigmoid')(y)
model = models.Model(x, y, name = 'FCNwithGAP')
model.summary()

model.compile(optimizer = 'rmsprop',
              loss = 'binary_crossentropy',
              metrics = ['acc'])
history = model.fit(x_train, y_train,
                    epochs = 20, 
                    batch_size = 128,
                    validation_split = 0.2)
plot_lcurve([history], [''], ['dodgerblue'])
# Out:
# Model: "FCNwithGAP"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None,
# Epoch 19/20
# 157/157 [==============================] - 1s 4ms/step - loss: 0.2101 - acc: 0.9215 - val_loss: 0.2817 - val_acc: 0.8894
# Epoch 20/20
# 157/157 [==============================] - 1s 4ms/step - loss: 0.2032 - acc: 0.9247 - val_loss: 0.2807 - val_acc: 0.8874

# %% [markdown]
# ## RNN
# ---

# %% [markdown]
# <p align='center'>
# <img src=https://res.cloudinary.com/dyd911kmh/image/upload/v1647442110/image6_f6vds6.png width=800>
# </p>

# %%
EMB_DIMS = 32
x = layers.Input(shape = MAX_LEN)
y = layers.Embedding(MAX_FEATURES, EMB_DIMS )(x)
y = layers.SimpleRNN(32)(y)
y = layers.Dense(1, activation = 'sigmoid')(y)
model = models.Model(x, y, name = 'FCNwithGAP')
model.summary()

model.compile(optimizer = 'rmsprop',
              loss = 'binary_crossentropy',
              metrics = ['acc'])
history = model.fit(x_train, y_train,
                    epochs = 5, 
                    batch_size = 128,
                    validation_split = 0.2)
plot_lcurve([history], [''], ['dodgerblue'])
# Out:
# Model: "FCNwithGAP"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256)]             0
#
#  embedding_1 (Embedding)     (None, 256, 32)           320000
#
#  simple_rnn (SimpleRNN)      (None, 32)                2080
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 322,113
# Trainable params: 322,113
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 157/157 [==============================] - 36s 224ms/step - loss: 0.6917 - acc: 0.5175 - val_loss: 0.6851 - val_acc: 0.5448
# Epoch 2/5
# 157/157 [==============================] - 34s 216ms/step - loss: 0.6575 - acc: 0.6057 - val_loss: 0.6603 - val_acc: 0.6260
# Epoch 3/5
# 157/157 [==============================] - 35s 220ms/step - loss: 0.6151 - acc: 0.6600 - val_loss: 0.5826 - val_acc: 0.7264
# Epoch 4/5
# 157/157 [==============================] - 34s 215ms/step - loss: 0.5128 - acc: 0.7646 - val_loss: 0.5025 - val_acc: 0.7860
# Epoch 5/5
# 157/157 [==============================] - 35s 222ms/step - loss: 0.4854 - acc: 0.7916 - val_loss: 0.5750 - val_acc: 0.7008

# %% [markdown]
# ## LSTM
# ---
#
# <p align='center'>
# <img src=https://res.cloudinary.com/dyd911kmh/image/upload/v1647442110/image3_nsnxp3.png width=600>
# </p>

# %%
EMB_DIMS = 32
x = layers.Input(shape = MAX_LEN)
y = layers.Embedding(MAX_FEATURES, EMB_DIMS )(x)
y = layers.LSTM(32)(y)
y = layers.Dense(1, activation = 'sigmoid')(y)
model = models.Model(x, y, name = 'LSTM')
model.summary()

model.compile(optimizer = 'rmsprop',
              loss = 'binary_crossentropy',
              metrics = ['acc'])
history = model.fit(x_train, y_train,
                    epochs = 20, 
                    batch_size = 128,
                    validation_split = 0.2)
plot_lcurve([history], [''], ['dodgerblue'])
# Out:
# Model: "LSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 256)]             0
#
#  embedding_2 (Embedding)     (None, 256, 32)           320000
#
#  lstm (LSTM)                 (None, 32)                8320
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 328,353
# Trainable params: 328,353
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
#
# </p>

# %%
EMB_DIMS = 32
x = layers.Input(shape = MAX_LEN)
y = layers.Embedding(MAX_FEATURES, EMB_DIMS )(x)
y = layers.LSTM(32, return_sequences = True)(y) # 2차 텐서가 출력된다 / many to many
y = layers.LSTM(32, return_sequences = False)(y) # 1차 텐서가 출력된다 / many to one
y = layers.Dense(1, activation = 'sigmoid')(y) 
model = models.Model(x, y, name = 'LSTM')
model.summary()

model.compile(optimizer = 'rmsprop',
              loss = 'binary_crossentropy',
              metrics = ['acc'])
history = model.fit(x_train, y_train,
                    epochs = 20, 
                    batch_size = 128,
                    validation_split = 0.2)
plot_lcurve([history], [''], ['dodgerblue'])
# Out:
# Model: "LSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 256)]             0
#
#  embedding_3 (Embedding)     (None, 256, 32)           320000
#
#  lstm_1 (LSTM)               (None, 256, 32)           8320
#
#  lstm_2 (LSTM)               (None, 32)                8320
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 336,673
# Trainable params: 336,673
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 157/157 [==============================] - 7s 26ms/step - loss: 0.6562 - acc: 0.5985 - val_loss: 0.5071 - val_acc: 0.7968
# Epoch 2/20
# 157/157 [==============================] - 3s 21ms/step - loss: 0.4949 - acc: 0.7814 - val_loss: 0.5632 - val_acc: 0.7512
# Epoch 3/20
# 157/157 [==============================] - 3s 21ms/step - loss: 0.4232 - acc: 0.8300 - val_loss: 0.4735 - val_acc: 0.8210
# Epoch 4/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.3399 - acc: 0.8785 - val_loss: 0.4070 - val_acc: 0.8460
# Epoch 5/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.3034 - acc: 0.8938 - val_loss: 0.3532 - val_acc: 0.8580
# Epoch 6/20
# 157/157 [==============================] - 4s 25ms/step - loss: 0.2743 - acc: 0.8978 - val_loss: 0.4073 - val_acc: 0.8670
# Epoch 7/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.2426 - acc: 0.9195 - val_loss: 0.4511 - val_acc: 0.7718
# Epoch 8/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.2318 - acc: 0.9219 - val_loss: 0.3723 - val_acc: 0.8756
# Epoch 9/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.2103 - acc: 0.9301 - val_loss: 0.3789 - val_acc: 0.8712
# Epoch 10/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.2073 - acc: 0.9304 - val_loss: 0.4306 - val_acc: 0.8428
# Epoch 11/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.2154 - acc: 0.9291 - val_loss: 0.3627 - val_acc: 0.8718
# Epoch 12/20
# 157/157 [==============================] - 3s 21ms/step - loss: 0.1903 - acc: 0.9408 - val_loss: 0.4552 - val_acc: 0.8660
# Epoch 13/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.1876 - acc: 0.9393 - val_loss: 0.4069 - val_acc: 0.8616
# Epoch 14/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.1974 - acc: 0.9316 - val_loss: 0.3960 - val_acc: 0.8674
# Epoch 15/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.2202 - acc: 0.9235 - val_loss: 0.4438 - val_acc: 0.8658
# Epoch 16/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.1952 - acc: 0.9333 - val_loss: 0.4023 - val_acc: 0.8678
# Epoch 17/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.2004 - acc: 0.9337 - val_loss: 0.3909 - val_acc: 0.8704
# Epoch 18/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.1967 - acc: 0.9376 - val_loss: 0.3975 - val_acc: 0.8716
# Epoch 19/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.1835 - acc: 0.9417 - val_loss: 1.0110 - val_acc: 0.7546
# Epoch 20/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.2085 - acc: 0.9323 - val_loss: 0.3807 - val_acc: 0.8626

# %% [markdown]
# ## GRU
# ---
#
#
# <p align='center'>
# <img src=https://res.cloudinary.com/dyd911kmh/image/upload/v1647442111/image10_zgefie.png width=600>
# </p>

# %%
EMB_DIMS = 32
x = layers.Input(shape = MAX_LEN)
y = layers.Embedding(MAX_FEATURES, EMB_DIMS )(x)
y = layers.GRU(32)(y)
y = layers.Dense(1, activation = 'sigmoid')(y) 
model = models.Model(x, y, name = 'LSTM')
model.summary()

model.compile(optimizer = 'rmsprop',
              loss = 'binary_crossentropy',
              metrics = ['acc'])
history = model.fit(x_train, y_train,
                    epochs = 20, 
                    batch_size = 128,
                    validation_split = 0.2)
plot_lcurve([history], [''], ['dodgerblue'])
# Out:
# Model: "LSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 256)]             0
#
#  embedding_4 (Embedding)     (None, 256, 32)           320000
#
#  gru (GRU)                   (None, 32)                6336
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 326,369
# Trainable params: 326,369
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 157/157 [==============================] - 4s 16ms/step - loss: 0.6909 - acc: 0.5261 - val_loss: 0.6667 - val_acc: 0.5694
# Epoch 2/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.7117 - acc: 0.6296 - val_loss: 0.7074 - val_acc: 0.7598
# Epoch 3/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.5885 - acc: 0.6754 - val_loss: 0.5450 - val_acc: 0.7184
# Epoch 4/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.4989 - acc: 0.7886 - val_loss: 0.4680 - val_acc: 0.8010
# Epoch 5/20
# 157/157 [==============================] - 2s 15ms/step - loss: 0.4386 - acc: 0.8303 - val_loss: 0.4480 - val_acc: 0.8292
# Epoch 6/20
# 157/157 [==============================] - 2s 15ms/step - loss: 0.4686 - acc: 0.8173 - val_loss: 0.4806 - val_acc: 0.8104
# Epoch 7/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3955 - acc: 0.8557 - val_loss: 0.4561 - val_acc: 0.8242
# Epoch 8/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3688 - acc: 0.8711 - val_loss: 0.4346 - val_acc: 0.8280
# Epoch 9/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3582 - acc: 0.8768 - val_loss: 0.4159 - val_acc: 0.8448
# Epoch 10/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3690 - acc: 0.8716 - val_loss: 0.4263 - val_acc: 0.8380
# Epoch 11/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3477 - acc: 0.8816 - val_loss: 0.4058 - val_acc: 0.8528
# Epoch 12/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3459 - acc: 0.8796 - val_loss: 0.4367 - val_acc: 0.8262
# Epoch 13/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3247 - acc: 0.8927 - val_loss: 0.4711 - val_acc: 0.8276
# Epoch 14/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3103 - acc: 0.8968 - val_loss: 0.4177 - val_acc: 0.8454
# Epoch 15/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3235 - acc: 0.8942 - val_loss: 0.4246 - val_acc: 0.8410
# Epoch 16/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.2948 - acc: 0.9044 - val_loss: 0.4985 - val_acc: 0.8198
# Epoch 17/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.2734 - acc: 0.9138 - val_loss: 0.4309 - val_acc: 0.8502
# Epoch 18/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.2771 - acc: 0.9110 - val_loss: 0.4137 - val_acc: 0.8540
# Epoch 19/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.2605 - acc: 0.9193 - val_loss: 0.3998 - val_acc: 0.8614
# Epoch 20/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.2480 - acc: 0.9238 - val_loss: 0.4099 - val_acc: 0.8550

# %% [markdown]
# ### | **many-to-many**
#
#
# <p align='center'>
# <img src=https://res.cloudinary.com/dyd911kmh/image/upload/v1647442111/image9_e1gwba.png width=700>
# </p>

# %%
EMB_DIMS = 32
x = layers.Input(shape = MAX_LEN)
y = layers.Embedding(MAX_FEATURES, EMB_DIMS )(x)
y = layers.GRU(32, return_sequences = True)(y)
y = layers.GRU(32, return_sequences = False)(y)
y = layers.Dense(1, activation = 'sigmoid')(y) 
model = models.Model(x, y, name = 'LSTM')
model.summary()

model.compile(optimizer = 'rmsprop',
              loss = 'binary_crossentropy',
              metrics = ['acc'])
history = model.fit(x_train, y_train,
                    epochs = 20, 
                    batch_size = 128,
                    validation_split = 0.2)
plot_lcurve([history], [''], ['dodgerblue'])
# Out:
# Model: "LSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 256)]             0
#
#  embedding_5 (Embedding)     (None, 256, 32)           320000
#
#  gru_1 (GRU)                 (None, 256, 32)           6336
#
#  gru_2 (GRU)                 (None, 32)                6336
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 332,705
# Trainable params: 332,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
#
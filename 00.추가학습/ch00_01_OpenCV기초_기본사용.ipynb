# %% [markdown]
# <a href="https://colab.research.google.com/github/pthkbs123/SkillTreePython-DeepLearning/blob/main/00.%EC%B6%94%EA%B0%80%ED%95%99%EC%8A%B5/ch00_01_OpenCV%EA%B8%B0%EC%B4%88_%EA%B8%B0%EB%B3%B8%EC%82%AC%EC%9A%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ch00.01. OpenCV기초 - 기본사용
#
# ---
# * 날짜: 2022-06-13
# * 이름: 박태현
#
# ## 학습내용
#     - OpenCV 이해하기
#     - OpenCV를 이용한 이미지 읽기
#     - OpenCV를 이용한 이미지 보기
#     - OpenCV를 이용한 이미지 Processing
#     - 이미지 저장하기
#
#
# ## 학습자료
# - [OpenCV 홈페이지](https://opencv.org/)
#
# - [OpenCV-pythoin Documentation](https://opencv-python.readthedocs.io/en/latest/)

# %% [markdown]
# ```
# import numpy as np
# import matplotlib.pyplot as plt
# import cv2
# cv2.__version__
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
cv2.__version__
# Out:
# '4.1.2'

# %% [markdown]
# ## OpenCV 소개
# ---
#
# - 영상처리 라이브러리
# - C++로 시작하여 3.0 파이썬 자바 제공
# - 딥러닝 라이브러리 대부분이 현재 파이썬
#
#
# 디지털 이미지를 편집할 때 가장 많이 사용되는  파일 유형
#
# ![](https://t1.daumcdn.net/cfile/tistory/2217E149551375980F)
#
# #### **벡터(vector) 그래픽스**
# 반응형 화면
# 전체하면-휴대폰화면 에서 비율을 깨지지 않고 보여줄 수 있다.
#
#
# #### **레스터(raster) 그래픽스**
#
# 비트맵, 알지비
# 오픈시브이 에서는 레스터 그래픽스 사용

# %% [markdown]
# ## 이미지 읽기 및 보기
# ---

# %% [markdown]
# ### **| 이미지 읽기**
#
#
# #### `cv2.imread(fileName), flage`
# * return : 넘파이 배열

# %% [markdown]
# #### **이미지 파일 준비**

# %% [markdown]
# * 파일 업로드
#
# ```
# from google.colab import files
# upload_file = files.upload()
# ```

# %%
from google.colab import files
upload_file = files.upload()
# Out:
#      <input type="file" id="files-ea8c732d-2d83-4756-9171-b98ed1d91f3d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ea8c732d-2d83-4756-9171-b98ed1d91f3d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sea.png to sea.png

# %% [markdown]
# * 파일 경로 설정

# %%
path = 'sea.png'

# %% [markdown]
# #### **Matplotlib과 비교**
#
# * Matploglib: RGB
#   * 이미지 불러오기 : plt.imread() -> RGB로 읽어옴
#   * 이미지 보여주기 : plt.imshow()
# * OpenCV : GBR
#   * 이미지 불러오기 : cv2.imread() -> GBR로 읽어옴
#   * 이미지 보여주기 : cv2.imshow()

# %%
# 불러오기
plt_img = plt.imread(path)
cv2_img = cv2.imread(path)

print(plt_img.shape, plt_img.dtype, type(plt_img))
print(cv2_img.shape, cv2_img.dtype, type(cv2_img))
print(plt_img[0][0], cv2_img[0][0])
# Out:
# (382, 635, 3) float32 <class 'numpy.ndarray'>
# (382, 635, 3) uint8 <class 'numpy.ndarray'>
# [0.26666668 0.4745098  0.49019608] [125 121  68]

# %% [markdown]
# * '이미지' 데이터

# %%
cv2_img[0]
# Out:
# array([[125, 121,  68],
#        [120, 116,  63],
#        [115, 111,  58],
#        ...,
#        [ 99,  85,  36],
#        [ 94,  80,  31],
#        [ 88,  74,  25]], dtype=uint8)

# %% [markdown]
# ### **| 이미지 보기**

# %% [markdown]
# #### **코랩 imshow 패치 함수**

# %% [markdown]
# * 원래 함수 : 코랩에서 사용불가
#
# ```
# cv2.imshow(name, image)
# ```

# %%
cv2.imshow('img', cv2_img)
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-14-d86f6436f161> in <module>()
# ----> 1 cv2.imshow('img', cv2_img)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      50   def wrapped(*args, **kwargs):
#      51     if not os.environ.get(env_var, False):
# ---> 52       raise DisabledFunctionError(message, name or func.__name__)
#      53     return func(*args, **kwargs)
#      54
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %% [markdown]
# * 코랩용 패치 함수
#
# ```
# from google.colab.patches import cv2_imshow
# cv2_imshow(cv2_img)
# ```

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(cv2_img)
# Out:
# <PIL.Image.Image image mode=RGB size=635x382 at 0x7F5285F35110>

# %% [markdown]
# #### **matplotlib으로 이미지 보기**

# %%
plt.subplot(121)
plt.imshow(plt_img)
plt.title('matplotlib')
plt.subplot(122)
plt.imshow(cv2_img)
plt.title('openCV')

# 이유
# imread()를 할 떄, plt : RGB로 불러옴
# 하지만 openCV는 GBR로 불러옴
# Out:
# Text(0.5, 1.0, 'openCV')

# %% [markdown]
# ## 이미지 Processing
# ---
#
# **이미지 좌표 형식**
#
# 디지털 영상은 2차원 행렬의 형태로 표현이 되며. 각 격자가 하나의 pixel이 됩니다.
# ![](https://opencv-python.readthedocs.io/en/latest/_images/image1.png)

# %% [markdown]
# ### **| Digital Image의 유형**

# %% [markdown]
# #### **Binary Image**
#
# Binary Image는 pixel당 1bit로 표현하는 영상을 의미합니다. 즉 흰색과 검은색으로만 표현이 되는 영상입니다.
#
# ![](https://opencv-python.readthedocs.io/en/latest/_images/image2.png)
#
#
# * 우측 상단 : thresholding처리를 하여 binary image로 변환
# * 우측 하단 : binary image의 밀도를 조절하여 밝기를 표현

# %% [markdown]
# #### **Grayscale Image**
#
# ![](https://opencv-python.readthedocs.io/en/latest/_images/image3.png)
#
# Grayscale Image는 Pixel당 8bit, 즉 256단계의 명암(빛의 세기)을 표현할 수 있는 이미지입니다.

# %% [markdown]
# #### **Color Image**
#
# * pixel의 색을 표현하기 위해서 채널별 pixel당 8bit 사용(0~255)
# * 총 16,777,216 가지의 색을 표현 (256x256x256)

# %% [markdown]
# #### **RGB Color-space vs HSV color-space**
#
#
# ![](https://opencv-python.readthedocs.io/en/latest/_images/image5.png)
# ![](https://opencv-python.readthedocs.io/en/latest/_images/image6.png)
#
# * RGB : 빛의 삼원색의 3채널
# * HSV : 색, 채도, 명도의 3채널

# %% [markdown]
# ### **| Color-space 변환**
#
# #### `cv2.cvtColor(src, code)`
# * Parameters:
#   * src : 이미지 배열
#   * code : 변환 코드

# %%
gray_img = cv2.cvtColor(cv2_img, cv2.COLOR_BGR2GRAY)
hsv_img = cv2.cvtColor(cv2_img, cv2.COLOR_BGR2HSV)
lab_img = cv2.cvtColor(cv2_img, cv2.COLOR_BGR2LAB)
rgb_img = cv2.cvtColor(cv2_img, cv2.COLOR_BGR2RGB)

plt.subplot(141)
plt.imshow(gray_img)
plt.title('gray_img')
plt.subplot(142)
plt.imshow(hsv_img)
plt.title('hsv_img')
plt.subplot(143)
plt.imshow(lab_img)
plt.title('lab_img')
plt.subplot(144)
plt.imshow(rgb_img)
plt.title('rgb_img')
# Out:
# Text(0.5, 1.0, 'rgb_img')

# %% [markdown]
# * plt로 변환 이미지 확인하기

# %%
for i, img in enumerate([gray_img, hsv_img, lab_img, rgb_img]):
  plt.subplot(2,2,i+1)
  plt.imshow(img) # cmap='gray
plt.show()

# %% [markdown]
# * cv2로 변환 이미지 확인하기

# %%
for i, img in enumerate([gray_img, hsv_img, lab_img, rgb_img]):
  cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=635x382 at 0x7F5283B170D0>
# <PIL.Image.Image image mode=RGB size=635x382 at 0x7F5283C348D0>
# <PIL.Image.Image image mode=RGB size=635x382 at 0x7F5283B70E10>
# <PIL.Image.Image image mode=RGB size=635x382 at 0x7F5283B70C50>

# %% [markdown]
# ## 이미지 저장
# ---
#
# #### `cv2.imwrite(fileName, image)`
# * Parameters
#   * fileName(str) : 저장될 파일명
#   * image : 저장할 이미지

# %%
cv2.imwrite('gray_img.png', gray_img)
# Out:
# True

# %% [markdown]
# ## 예제
# ---
#   * 동물 사진 1장
#   * 차량 혹은 도로 위 차량 사진 1장
#
# Color space 변환 적용 해보기 (다른 변환 코드)

# %%
animal = cv2.imread('cat.jpg')
car = cv2.imread('car.jpg')

cv2_imshow(animal)
cv2_imshow(car)

lab_animal = cv2.cvtColor(animal, cv2.COLOR_BGR2LAB)
lab_car = cv2.cvtColor(car, cv2.COLOR_BGR2LAB)

cv2_imshow(lab_animal)
cv2_imshow(lab_car)
# Out:
# <PIL.Image.Image image mode=RGB size=600x399 at 0x7F5283C43750>
# <PIL.Image.Image image mode=RGB size=519x253 at 0x7F5283A93990>
# <PIL.Image.Image image mode=RGB size=600x399 at 0x7F5283C08290>
# <PIL.Image.Image image mode=RGB size=519x253 at 0x7F5283D93510>

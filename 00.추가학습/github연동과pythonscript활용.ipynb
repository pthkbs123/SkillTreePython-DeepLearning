# %% [markdown]
# <a href="https://colab.research.google.com/github/pthkbs123/SkillTreePython-DeepLearning/blob/main/00.%EC%B6%94%EA%B0%80%ED%95%99%EC%8A%B5/github%EC%97%B0%EB%8F%99%EA%B3%BCpythonscript%ED%99%9C%EC%9A%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 라이브러리 로드

# %% [markdown]
# * 깃허브 레포지토리 복사

# %%
! git clone https://github.com/pthkbs123/SkillTreePython-DeepLearning
# Out:
# fatal: destination path 'SkillTreePython-DeepLearning' already exists and is not an empty directory.

# %% [markdown]
# * weight 파일 다운로드 (용량이 큰 데이터는 깃허브에 저장 하지 않는걸 권장)

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights -O yolov3.weights
# Out:
# --2022-06-22 05:04:34--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  38.9MB/s    in 6.4s
#
# 2022-06-22 05:04:41 (36.8 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %% [markdown]
# ## 세팅

# %% [markdown]
# * 라이브러리 임포트

# %%
PATH = '/content/SkillTreePython-DeepLearning/00.추가학습/data'
import sys
sys.path.append(PATH)
from detect_to_plate import *

# %% [markdown]
# * 모델과 클래스 정보 로드 (한번만 실행)

# %%
weight_file = '/content/yolov3.weights'
cfg_file = f'/{PATH}/yolov3.cfg' 
name_file = f'/{PATH}/coco.names'
model, predict_layer_names = set_model(weight_file, cfg_file)
class_names, class_colors = set_label(name_file)

# %% [markdown]
# ## 이미지 실행

# %%
img_name = 'test_car3.jpg' #@param ['test_car3.jpg', 'test_car2.jpg', 'test_car.jpg'] 
img_path = f'/{PATH}/{img_name}'
img = cv2.imread(img_path)
plate2detect(img,weight_file, cfg_file)
# Out:
# <PIL.Image.Image image mode=RGB size=940x626 at 0x7FED2F9E6F90>

# %% [markdown]
# ## 영상 실행

# %%
cap = cv2.VideoCapture(f'{PATH}/car_test_video.mp4') # 비디오 캡쳐
while True:
  _, frame = cap.read() # 캡쳐로부터 비디오 프레임 얻기
  if frame is None: # 프레임 끝나면 종료
    print('No frame !')
    break
  plate2detect(frame,weight_file, cfg_file)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7FED2CDBD4D0>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-04048fe3739e> in <module>()
#       5     print('No frame !')
#       6     break
# ----> 7   plate2detect(frame,weight_file, cfg_file)
#
# /content/SkillTreePython-DeepLearning/00.추가학습/data/detect_to_plate.py in plate2detect(img, weight_file, cfg_file)
#      79   # 이미지 불러와서 yolo 모델 적용
#      80   model, predict_layer_names = set_model(weight_file, cfg_file)
# ---> 81   boxes, confidences, class_ids = get_preds(img, model, predict_layer_names)
#      82
#      83   plate_cascade_name = '/content/SkillTreePython-DeepLearning/00.추가학습/data/haarcascade_russian_plate_number.xml'
#
# /content/SkillTreePython-DeepLearning/00.추가학습/data/detect_to_plate.py in get_preds(img, model, predict_layer_names, min_confidence)
# ...

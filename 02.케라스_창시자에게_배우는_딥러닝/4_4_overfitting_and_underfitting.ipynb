# %% [markdown]
# <a href="https://colab.research.google.com/github/pthkbs123/SkillTreePython-DeepLearning/blob/main/02.%EC%BC%80%EB%9D%BC%EC%8A%A4_%EC%B0%BD%EC%8B%9C%EC%9E%90%EC%97%90%EA%B2%8C_%EB%B0%B0%EC%9A%B0%EB%8A%94_%EB%94%A5%EB%9F%AC%EB%8B%9D/4_4_overfitting_and_underfitting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 과대적합과 과소적합
#
# 이 노트북은 [케라스 창시자에게 배우는 딥러닝](https://tensorflow.blog/%EC%BC%80%EB%9D%BC%EC%8A%A4-%EB%94%A5%EB%9F%AC%EB%8B%9D/) 책의 4장 4절의 코드 예제입니다. 책에는 더 많은 내용과 그림이 있습니다. 이 노트북에는 소스 코드에 관련된 설명만 포함합니다.
#
# ----
#
# 이전 장에 있던 세 가지 예제인 영화 리뷰 예측, 토픽 분류, 주택 가격 회귀 모두 홀드아웃 데이터에서 모델의 성능이 몇 번의 에포크 후에 최고치에 다다랐다가 감소되기 시작했습니다. 즉, 모델이 금방 훈련 데이터에 과대적합되기 시작합니다. 과대적합은 모든 머신 러닝 문제에서 발생합니다. 머신 러닝을 마스터하려면 과대적합을 다루는 방법을 꼭 배워야 합니다.
#
# 머신 러닝의 근본적인 이슈는 최적화와 일반화 사이의 줄다리기입니다. 최적화는 가능한 훈련 데이터에서 최고의 성능을 얻으려고 모델을 조정하는 과정입니다(머신 러닝의 학습). 반면 일반화는 훈련된 모델이 이전에 본 적 없는 데이터에서 얼마나 잘 수행되는지를 의미합니다. 물론 모델을 만드는 목적은 좋은 일반화 성능을 얻는 것입니다. 하지만 일반화 성능을 제어할 방법이 없습니다. 단지 훈련 데이터를 기반으로 모델을 조정할 수만 있습니다.
#
# 훈련 초기에 최적화와 일반화는 상호 연관되어 있습니다. 훈련 데이터의 손실이 낮을수록 테스트 데이터의 손실이 낮습니다. 이런 상황이 발생할 때 모델이 과소적합되었다고 말합니다. 모델의 성능이 계속 발전될 여지가 있습니다. 즉, 네트워크가 훈련 데이터에 있는 관련 특성을 모두 학습하지 못했습니다. 하지만 훈련 데이터에 여러 번 반복 학습하고 나면 어느 시점부터 일반화 성능이 더이상 높아지지 않습니다. 검증 세트의 성능이 멈추고 감소되기 시작합니다. 즉, 모델이 과대적합되기 시작합니다. 이는 훈련 데이터에 특화된 패턴을 학습하기 시작했다는 의미입니다. 이 패턴은 새로운 데이터와 관련성이 적어 잘못된 판단을 하게 만듭니다.
#
# 모델이 관련성이 없고 좋지 못한 패턴을 훈련 데이터에서 학습하지 못하도록 하려면 가장 좋은 방법은 더 많은 훈련 데이터를 모으는 것입니다. 더 많은 데이터에서 훈련된 모델은 자연히 일반화 성능이 더 뛰어 납니다. 데이터를 더 모으는 것이 불가능할 때 차선책은 모델이 수용할 수 있는 정보의 양을 조절하거나 저장할 수 있는 정보에 제약을 가하는 것입니다. 네트워크가 적은 수의 패턴만을 기억할 수 있다면 최적화 과정에서 가장 중요한 패턴에 집중하게 될 것입니다. 이런 패턴은 더 나은 일반화 성능을 제공할 수 있습니다.
#
# 이런 식으로 과대적합을 피하는 처리 과정을 규제라고 합니다. 가장 널리 사용되는 규제 기법을 알아보고 이전 장에서 본 영화 리뷰 분류 모델에 실제로 적용해 성능을 향상시켜 보겠습니다.

# %% [markdown]
# 노트: 이 노트북에서는 편의상 IMDB 테스트 세트를 검증 세트로 사용합니다.
#
# 3장 5절에 있는 코드를 사용해 데이터를 준비합니다:

# %%
from tensorflow.keras import datasets
import numpy as np

# %%
(x_train,y_train), (x_test,y_test) = datasets.imdb.load_data(num_words=10000) # 텍스트 데이터
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# 샘플수 : 25000개
for i in range(5):
  print(len(x_train[i]), x_train[i])
  print(y_train[i])
# Out:
# (25000,) (25000,) (25000,) (25000,)
# 218 [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]
# 1
# 189 [1, 194, 1153, 194, 8255, 78, 228, 5, 6, 1463, 4369, 5012, 134, 26, 4, 715, 8, 118, 1634, 14, 394, 20, 13, 119, 954, 189, 102, 5, 207, 110, 3103, 21, 14, 69, 188, 8, 30, 23, 7, 4, 249, 126, 93, 4, 114, 9, 2300, 1523, 5, 647, 4, 116, 9, 35, 8163, 4, 229, 9, 340, 1322, 4, 118, 9, 4, 130, 4901, 19, 4, 1002, 5, 89, 29, 952, 46, 37, 4, 455, 9, 45, 43, 38, 1543, 1905, 398, 4, 1649, 26, 6853, 5, 163, 11, 3215, 2, 4, 1153, 9, 194, 775, 7, 8255, 2, 349, 2637, 148, 605, 2, 8003, 15, 123, 125, 68, 2, 6853, 15, 349, 165, 4362, 98, 5, 4, 228, 9, 43, 2, 1157, 15, 299, 120, 5, 120, 174, 11, 220, 175, 136, 50, 9, 4373, 228, 8255, 5, 2, 656, 245, 2350, 5, 4, 9837, 131, 152, 491, 18, 2, 32, 7464, 1212, 14, 9, 6, 371, 78, 22, 625, 64, 1382, 9, 8, 168, 145, 23, 4, 1690, 15, 16, 4, 1355, 5, 28, 6, 52, 154, 462, 33, 89, 78, 285, 16, 145, 95]
# 0
# 141 [1, 14, 47, 8, 30, 31, 7, 4, 249, 108, 7, 4, 5974, 54, 61, 369, 13, 71, 149, 14, 22, 112, 4, 2401, 311, 12, 16, 3711, 33, 75, 43, 1829, 296, 4, 86, 320, 35, 534, 19, 263, 4821, 1301, 4, 1873, 33, 89, 78, 12, 66, 16, 4, 360, 7, 4, 58, 316, 334, 11, 4, 1716, 43, 645, 662, 8, 257, 85, 1200, 42, 1228, 2578, 83, 68, 3912, 15, 36, 165, 1539, 278, 36, 69, 2, 780, 8, 106, 14, 6905, 1338, 18, 6, 22, 12, 215, 28, 610, 40, 6, 87, 326, 23, 2300, 21, 23, 22, 12, 272, 40, 57, 31, 11, 4, 22, 47, 6, 2307, 51, 9, 170, 23, 595, 116, 595, 1352, 13, 191, 79, 638, 89, 2, 14, 9, 8, 106, 607, 624, 35, 534, 6, 227, 7, 129, 113]
# 0
# 550 [1, 4, 2, 2, 33, 2804, 4, 2040, 432, 111, 153, 103, 4, 1494, 13, 70, 131, 67, 11, 61, 2, 744, 35, 3715, 761, 61, 5766, 452, 9214, 4, 985, 7, 2, 59, 166, 4, 105, 216, 1239, 41, 1797, 9, 15, 7, 35, 744, 2413, 31, 8, 4, 687, 23, 4, 2, 7339, 6, 3693, 42, 38, 39, 121, 59, 456, 10, 10, 7, 265, 12, 575, 111, 153, 159, 59, 16, 1447, 21, 25, 586, 482, 39, 4, 96, 59, 716, 12, 4, 172, 65, 9, 579, 11, 6004, 4, 1615, 5, 2, 7, 5168, 17, 13, 7064, 12, 19, 6, 464, 31, 314, 11, 2, 6, 719, 605, 11, 8, 202, 27, 310, 4, 3772, 3501, 8, 2722, 58, 10, 10, 537, 2116, 180, 40, 14, 413, 173, 7, 263, 112, 37, 152, 377, 4, 537, 263, 846, 579, 178, 54, 75, 71, 476, 36, 413, 263, 2504, 182, 5, 17, 75, 2306, 922, 36, 279, 131, 2895, 17, 2867, 42, 17, 35, 921, 2, 192, 5, 1219, 3890, 19, 2, 217, 4122, 1710, 537, 2, 1236, 5, 736, 10, 10, 61, 403, 9, 2, 40, 61, 4494, 5, 27, 4494, 159, 90, 263, 2311, 4319, 309, 8, 178, 5, 82, 4319, 4, 65, 15, 9225, 145, 143, 5122, 12, 7039, 537, 746, 537, 537, 15, 7979, 4, 2, 594, 7, 5168, 94, 9096, 3987, 2, 11, 2, 4, 538, 7, 1795, 246, 2, 9, 2, 11, 635, 14, 9, 51, 408, 12, 94, 318, 1382, 12, 47, 6, 2683, 936, 5, 6307, 2, 19, 49, 7, 4, 1885, 2, 1118, 25, 80, 126, 842, 10, 10, 2, 2, 4726, 27, 4494, 11, 1550, 3633, 159, 27, 341, 29, 2733, 19, 4185, 173, 7, 90, 2, 8, 30, 11, 4, 1784, 86, 1117, 8, 3261, 46, 11, 2, 21, 29, 9, 2841, 23, 4, 1010, 2, 793, 6, 2, 1386, 1830, 10, 10, 246, 50, 9, 6, 2750, 1944, 746, 90, 29, 2, 8, 124, 4, 882, 4, 882, 496, 27, 2, 2213, 537, 121, 127, 1219, 130, 5, 29, 494, 8, 124, 4, 882, 496, 4, 341, 7, 27, 846, 10, 10, 29, 9, 1906, 8, 97, 6, 236, 2, 1311, 8, 4, 2, 7, 31, 7, 2, 91, 2, 3987, 70, 4, 882, 30, 579, 42, 9, 12, 32, 11, 537, 10, 10, 11, 14, 65, 44, 537, 75, 2, 1775, 3353, 2, 1846, 4, 2, 7, 154, 5, 4, 518, 53, 2, 2, 7, 3211, 882, 11, 399, 38, 75, 257, 3807, 19, 2, 17, 29, 456, 4, 65, 7, 27, 205, 113, 10, 10, 2, 4, 2, 2, 9, 242, 4, 91, 1202, 2, 5, 2070, 307, 22, 7, 5168, 126, 93, 40, 2, 13, 188, 1076, 3222, 19, 4, 2, 7, 2348, 537, 23, 53, 537, 21, 82, 40, 2, 13, 2, 14, 280, 13, 219, 4, 2, 431, 758, 859, 4, 953, 1052, 2, 7, 5991, 5, 94, 40, 25, 238, 60, 2, 4, 2, 804, 2, 7, 4, 9941, 132, 8, 67, 6, 22, 15, 9, 283, 8, 5168, 14, 31, 9, 242, 955, 48, 25, 279, 2, 23, 12, 1685, 195, 25, 238, 60, 796, 2, 4, 671, 7, 2804, 5, 4, 559, 154, 888, 7, 726, 50, 26, 49, 7008, 15, 566, 30, 579, 21, 64, 2574]
# 1
# 147 [1, 249, 1323, 7, 61, 113, 10, 10, 13, 1637, 14, 20, 56, 33, 2401, 18, 457, 88, 13, 2626, 1400, 45, 3171, 13, 70, 79, 49, 706, 919, 13, 16, 355, 340, 355, 1696, 96, 143, 4, 22, 32, 289, 7, 61, 369, 71, 2359, 5, 13, 16, 131, 2073, 249, 114, 249, 229, 249, 20, 13, 28, 126, 110, 13, 473, 8, 569, 61, 419, 56, 429, 6, 1513, 18, 35, 534, 95, 474, 570, 5, 25, 124, 138, 88, 12, 421, 1543, 52, 725, 6397, 61, 419, 11, 13, 1571, 15, 1543, 20, 11, 4, 2, 5, 296, 12, 3524, 5, 15, 421, 128, 74, 233, 334, 207, 126, 224, 12, 562, 298, 2167, 1272, 7, 2601, 5, 516, 988, 43, 8, 79, 120, 15, 595, 13, 784, 25, 3171, 18, 165, 170, 143, 19, 14, 5, 7224, 6, 226, 251, 7, 61, 113]
# 0

# %%
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

x_train = vectorize_sequences(x_train)
x_test = vectorize_sequences(x_test)
y_train = np.asarray(y_train).astype('float32')
y_test = np.asarray(y_test).astype('float32')
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
print(x_train[0], y_train[0])
# Out:
# (25000, 10000) (25000,) (25000, 10000) (25000,)
# [0. 1. 1. ... 0. 0. 0.] 1.0

# %% [markdown]
# # 과대적합
#
# ## 네트워크 크기 축소
#
# 과대적합을 막는 가장 단순한 방법은 모델의 크기, 즉 모델에 있는 학습 파라미터의 수를 줄이는 것입니다. 파라미터의 수는 층의 수와 각 층의 유닛 수에 의해 결정됩니다. 딥러닝에서 모델에 있는 학습 파라미터의 수를 종종 모델의 용량이라고 말합니다. 당연하게 파라미터가 많은 모델이 기억 용량이 더 많습니다. 훈련 샘플과 타깃 사이를 딕셔너리와 같은 1:1 매핑으로 완벽하게 학습할 수도 있습니다. 이런 매핑은 일반화 능력이 없습니다. 예를 들어 500,000개의 이진 파라미터가 있는 모델은 MNIST 훈련 세트의 숫자 이미지의 클래스를 쉽게 모두 학습할 수 있습니다. 50,000개의 숫자 이미지 하나마다 10개의 이진 파라미터만 있으면 됩니다. 하지만 이런 모델은 새로운 숫자 샘플을 분류하는 용도로는 쓸모가 없습니다. 항상 유념해야 할 것은 딥러닝 모델은 훈련 데이터에 잘 맞으려는 경향을 가진다는 점입니다. 하지만 진짜 문제는 최적화가 아니고 일반화입니다.
#
# 다른 한편으로 네트워크가 기억 용량에 제한이 있다면 이런 매핑을 쉽게 학습하지 못할 것입니다. 따라서 손실을 최소화하기 위해 타깃에 대한 예측 성능을 가진 압축된 표현을 학습해야 합니다. 정확히 이런 표현이 우리의 관심 대상입니다. 동시에 기억해야할 것은 과소적합되지 않도록 충분한 파라미터를 가진 모델을 사용해야 한다는 점입니다. 모델의 기억 용량이 부족해서는 안 됩니다. 너무 많은 용량과 충분하지 않은 용량 사이의 절충점을 찾아야 합니다.
#
# 안타깝지만 알맞은 층의 수나 각 층의 유닛 수를 결정할 수 있는 마법 같은 공식은 없습니다. 데이터에 알맞는 모델 크기를 찾으려면 각기 다른 구조를 (당연히 테스트 세트가 아니고 검증 세트에서) 평가해 보아야 합니다. 적절한 모델 크기를 찾는 일반적인 작업 흐름은 비교적 적은 수의 층과 파라미터로 시작합니다. 그다음 검증 손실이 감소되기 시작할 때까지 층이나 유닛의 수를 늘리는 것입니다.
#
# 영화 리뷰 분류 모델에 적용해 보죠. 원래 네트워크는 다음과 같습니다:

# %%
from tensorflow.keras import models, layers, utils

def build_org():
  x = layers.Input(shape = (10000))
  y = layers.Dense(16, activation = 'relu')(x)
  y = layers.Dense(16, activation = 'relu')(y)
  y = layers.Dense(1, activation = 'sigmoid')(y)
  return models.Model(x,y, name = 'Org')

org = build_org()
org.summary()
org.compile(optimizer='rmsprop',
            loss='binary_crossentropy',
            metrics=['acc'])
# Out:
# Model: "Org"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 10000)]           0
#
#  dense_21 (Dense)            (None, 16)                160016
#
#  dense_22 (Dense)            (None, 16)                272
#
#  dense_23 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 더 작은 네트워크로 바꾸어 보죠:

# %%
from tensorflow.keras import models, layers, utils

def build_small():
  x = layers.Input(shape = (10000))
  y = layers.Dense(6, activation = 'relu')(x)
  y = layers.Dense(6, activation = 'relu')(y)
  y = layers.Dense(1, activation = 'sigmoid')(y)
  return models.Model(x,y, name = 'Small')

small = build_small()
small.summary()
small.compile(optimizer='rmsprop',
            loss='binary_crossentropy',
            metrics=['acc'])
# Out:
# Model: "Small"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 10000)]           0
#
#  dense_27 (Dense)            (None, 6)                 60006
#
#  dense_28 (Dense)            (None, 6)                 42
#
#  dense_29 (Dense)            (None, 1)                 7
#
# =================================================================
# Total params: 60,055
# Trainable params: 60,055
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 원본 네트워크와 축소된 네트워크의 검증 손실을 비교해 보죠.

# %%
org_hist = org.fit(x_train, y_train,
                   epochs = 20, batch_size = 512,
                   validation_data = (x_test,y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 4s 54ms/step - loss: 0.4573 - acc: 0.8182 - val_loss: 0.3399 - val_acc: 0.8763
# Epoch 2/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2609 - acc: 0.9078 - val_loss: 0.2849 - val_acc: 0.8903
# Epoch 3/20
# 49/49 [==============================] - 2s 40ms/step - loss: 0.1989 - acc: 0.9295 - val_loss: 0.3009 - val_acc: 0.8785
# Epoch 4/20
# 49/49 [==============================] - 2s 40ms/step - loss: 0.1651 - acc: 0.9427 - val_loss: 0.2935 - val_acc: 0.8836
# Epoch 5/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.1400 - acc: 0.9507 - val_loss: 0.3162 - val_acc: 0.8782
# Epoch 6/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.1198 - acc: 0.9586 - val_loss: 0.3354 - val_acc: 0.8759
# Epoch 7/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.1052 - acc: 0.9654 - val_loss: 0.3617 - val_acc: 0.8720
# Epoch 8/20
# 49/49 [==============================] - 2s 41ms/step - loss: 0.0893 - acc: 0.9705 - val_loss: 0.3879 - val_acc: 0.8700
# Epoch 9/20
# 49/49 [==============================] - 2s 40ms/step - loss: 0.0766 - acc: 0.9761 - val_loss: 0.4179 - val_acc: 0.8665
# Epoch 10/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.0659 - acc: 0.9798 - val_loss: 0.4559 - val_acc: 0.8620
# Epoch 11/20
# 49/49 [==============================] - 2s 40ms/step - loss: 0.0554 - acc: 0.9838 - val_loss: 0.4878 - val_acc: 0.8614
# Epoch 12/20
# 49/49 [==============================] - 2s 40ms/step - loss: 0.0456 - acc: 0.9875 - val_loss: 0.5179 - val_acc: 0.8619
# Epoch 13/20
# 49/49 [==============================] - 2s 41ms/step - loss: 0.0394 - acc: 0.9897 - val_loss: 0.5677 - val_acc: 0.8512
# Epoch 14/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.0306 - acc: 0.9920 - val_loss: 0.5725 - val_acc: 0.8589
# Epoch 15/20
# 49/49 [==============================] - 2s 40ms/step - loss: 0.0278 - acc: 0.9930 - val_loss: 0.6115 - val_acc: 0.8554
# Epoch 16/20
# 49/49 [==============================] - 2s 40ms/step - loss: 0.0210 - acc: 0.9950 - val_loss: 0.6521 - val_acc: 0.8562
# Epoch 17/20
# 49/49 [==============================] - 2s 40ms/step - loss: 0.0166 - acc: 0.9962 - val_loss: 0.6853 - val_acc: 0.8544
# Epoch 18/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.0158 - acc: 0.9959 - val_loss: 0.7244 - val_acc: 0.8535
# Epoch 19/20
# 49/49 [==============================] - 2s 40ms/step - loss: 0.0114 - acc: 0.9976 - val_loss: 0.7577 - val_acc: 0.8520
# Epoch 20/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.0099 - acc: 0.9980 - val_loss: 0.7993 - val_acc: 0.8511

# %%
small_hist = small.fit(x_train, y_train,
                       epochs = 20, batch_size = 512,
                       validation_data = (x_test,y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 3s 48ms/step - loss: 0.5305 - acc: 0.8020 - val_loss: 0.4293 - val_acc: 0.8588
# Epoch 2/20
# 49/49 [==============================] - 2s 37ms/step - loss: 0.3418 - acc: 0.8976 - val_loss: 0.3299 - val_acc: 0.8825
# Epoch 3/20
# 49/49 [==============================] - 2s 37ms/step - loss: 0.2524 - acc: 0.9190 - val_loss: 0.2929 - val_acc: 0.8879
# Epoch 4/20
# 49/49 [==============================] - 2s 36ms/step - loss: 0.2057 - acc: 0.9301 - val_loss: 0.2802 - val_acc: 0.8902
# Epoch 5/20
# 49/49 [==============================] - 2s 36ms/step - loss: 0.1769 - acc: 0.9400 - val_loss: 0.2822 - val_acc: 0.8881
# Epoch 6/20
# 49/49 [==============================] - 2s 36ms/step - loss: 0.1559 - acc: 0.9482 - val_loss: 0.2944 - val_acc: 0.8840
# Epoch 7/20
# 49/49 [==============================] - 2s 37ms/step - loss: 0.1391 - acc: 0.9538 - val_loss: 0.3045 - val_acc: 0.8822
# Epoch 8/20
# 49/49 [==============================] - 2s 37ms/step - loss: 0.1275 - acc: 0.9577 - val_loss: 0.3148 - val_acc: 0.8801
# Epoch 9/20
# 49/49 [==============================] - 2s 37ms/step - loss: 0.1141 - acc: 0.9636 - val_loss: 0.3320 - val_acc: 0.8771
# Epoch 10/20
# 49/49 [==============================] - 2s 37ms/step - loss: 0.1045 - acc: 0.9666 - val_loss: 0.3746 - val_acc: 0.8677
# Epoch 11/20
# 49/49 [==============================] - 2s 37ms/step - loss: 0.0952 - acc: 0.9704 - val_loss: 0.3665 - val_acc: 0.8726
# Epoch 12/20
# 49/49 [==============================] - 2s 37ms/step - loss: 0.0867 - acc: 0.9734 - val_loss: 0.3880 - val_acc: 0.8699
# Epoch 13/20
# 49/49 [==============================] - 2s 37ms/step - loss: 0.0792 - acc: 0.9757 - val_loss: 0.4060 - val_acc: 0.8688
# Epoch 14/20
# 49/49 [==============================] - 2s 37ms/step - loss: 0.0726 - acc: 0.9782 - val_loss: 0.4269 - val_acc: 0.8666
# Epoch 15/20
# 49/49 [==============================] - 2s 37ms/step - loss: 0.0653 - acc: 0.9813 - val_loss: 0.4528 - val_acc: 0.8626
# Epoch 16/20
# 49/49 [==============================] - 2s 36ms/step - loss: 0.0603 - acc: 0.9838 - val_loss: 0.4709 - val_acc: 0.8628
# Epoch 17/20
# 49/49 [==============================] - 2s 36ms/step - loss: 0.0540 - acc: 0.9858 - val_loss: 0.4976 - val_acc: 0.8617
# Epoch 18/20
# 49/49 [==============================] - 2s 36ms/step - loss: 0.0491 - acc: 0.9878 - val_loss: 0.5258 - val_acc: 0.8578
# Epoch 19/20
# 49/49 [==============================] - 2s 36ms/step - loss: 0.0437 - acc: 0.9898 - val_loss: 0.5527 - val_acc: 0.8597
# Epoch 20/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.0408 - acc: 0.9899 - val_loss: 0.5726 - val_acc: 0.8578

# %%
import matplotlib.pyplot as plt



def plot_lcurve(hists, titles, colors):
  plt.figure(figsize = (12,4))
  # loss
  plt.subplot(121)
  for i,hist in enumerate(hists):
    
    loss = hist.history['loss']
    val_loss = hist.history['val_loss']
    epochs = range(1, 1+len(loss))
    plt.plot(epochs, loss, linestyle = ':', label = f'{titles[i]} train loss', c = colors[i])
    plt.plot(epochs, val_loss, marker = '.', label = f'{titles[i]} val_loss', c = colors[i])
    plt.legend();plt.grid(True);plt.xticks(epochs)
    plt.xlabel('Epochs');plt.ylabel('Loss')

    x, y = epochs[-1], hist.history['loss'][-1]
    plt.text(x, y, np.round(y,2), c = colors[i])
    x, y = epochs[-1], hist.history['val_loss'][-1]
    plt.text(x, y, np.round(y,2), c = colors[i])
  # acc
  plt.subplot(122)
  for i,hist in enumerate(hists):
    acc = hist.history['acc']
    val_acc = hist.history['val_acc']
    
    epochs = range(1, 1+len(loss))
    plt.plot(epochs, acc, linestyle = ':', label = f'{titles[i]} train acc', c = colors[i])
    plt.plot(epochs, val_acc, marker = '.', label = f'{titles[i]} val_acc', c = colors[i])
    plt.legend();plt.grid(True);plt.xticks(epochs)
    plt.xlabel('Epochs');plt.ylabel('Acc')

    x, y = epochs[-1], hist.history['acc'][-1]
    plt.text(x, y, np.round(y,2), c = colors[i])
    x, y = epochs[-1], hist.history['val_acc'][-1]
    plt.text(x, y, np.round(y,2), c = colors[i])

  plt.show()

# %%
hists = [org_hist, small_hist]
titles = ['org','small']
colors = ['dodgerblue', 'orangered']
plot_lcurve(hists, titles, colors)

# %% [markdown]
# 여기서 볼 수 있듯이 작은 네트워크가 기본 네트워크보다 더 나중에 과대적합되기 시작했습니다(네 번째 에포크가 아니라 여섯 번째 에포크에서). 과대적합이 시작되었을 때 성능이 더 천천히 감소되었습니다.
#
# 이번에는 문제에 필요한 것보다 훨씬 더 많은 용량을 가진 네트워크를 비교해 보겠습니다:

# %%
from tensorflow.keras import models, layers, utils

def build_big():
  x = layers.Input(shape = (10000))
  y = layers.Dense(1024, activation = 'relu')(x)
  y = layers.Dense(1024, activation = 'relu')(y)
  y = layers.Dense(1, activation = 'sigmoid')(y)
  return models.Model(x,y, name = 'Small')

big = build_big()
big.summary()
big.compile(optimizer='rmsprop',
            loss='binary_crossentropy',
            metrics=['acc'])
# Out:
# Model: "Small"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 10000)]           0
#
#  dense_30 (Dense)            (None, 1024)              10241024
#
#  dense_31 (Dense)            (None, 1024)              1049600
#
#  dense_32 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 11,291,649
# Trainable params: 11,291,649
# Non-trainable params: 0
# _________________________________________________________________

# %%
big_hist = big.fit(x_train, y_train,
                       epochs = 20, batch_size = 512,
                       validation_data = (x_test,y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 38s 769ms/step - loss: 0.5428 - acc: 0.7896 - val_loss: 0.3392 - val_acc: 0.8467
# Epoch 2/20
# 49/49 [==============================] - 37s 757ms/step - loss: 0.2240 - acc: 0.9106 - val_loss: 0.2881 - val_acc: 0.8797
# Epoch 3/20
# 49/49 [==============================] - 38s 780ms/step - loss: 0.1164 - acc: 0.9580 - val_loss: 0.3433 - val_acc: 0.8859
# Epoch 4/20
# 49/49 [==============================] - 41s 838ms/step - loss: 0.0813 - acc: 0.9828 - val_loss: 0.4249 - val_acc: 0.8849
# Epoch 5/20
# 49/49 [==============================] - 35s 712ms/step - loss: 0.0938 - acc: 0.9863 - val_loss: 0.4639 - val_acc: 0.8841
# Epoch 6/20
# 49/49 [==============================] - 37s 763ms/step - loss: 0.0014 - acc: 0.9998 - val_loss: 2.4922 - val_acc: 0.7375
# Epoch 7/20
# 49/49 [==============================] - 36s 734ms/step - loss: 0.1149 - acc: 0.9865 - val_loss: 0.6408 - val_acc: 0.8828
# Epoch 8/20
# 49/49 [==============================] - 33s 680ms/step - loss: 0.1638 - acc: 0.9866 - val_loss: 0.5805 - val_acc: 0.8802
# Epoch 9/20
# 49/49 [==============================] - 33s 677ms/step - loss: 2.2785e-04 - acc: 1.0000 - val_loss: 0.6764 - val_acc: 0.8804
# Epoch 10/20
# 49/49 [==============================] - 34s 701ms/step - loss: 3.1894e-05 - acc: 1.0000 - val_loss: 0.8037 - val_acc: 0.8815
# Epoch 11/20
# 49/49 [==============================] - 33s 674ms/step - loss: 5.3694e-06 - acc: 1.0000 - val_loss: 0.9407 - val_acc: 0.8805
# Epoch 12/20
# 49/49 [==============================] - 38s 780ms/step - loss: 8.0201e-07 - acc: 1.0000 - val_loss: 1.0784 - val_acc: 0.8805
# Epoch 13/20
# 49/49 [==============================] - 33s 671ms/step - loss: 1.4351e-07 - acc: 1.0000 - val_loss: 1.2073 - val_acc: 0.8812
# Epoch 14/20
# 49/49 [==============================] - 33s 672ms/step - loss: 3.4095e-08 - acc: 1.0000 - val_loss: 1.2936 - val_acc: 0.8812
# Epoch 15/20
# 49/49 [==============================] - 33s 678ms/step - loss: 1.4745e-08 - acc: 1.0000 - val_loss: 1.3401 - val_acc: 0.8815
# Epoch 16/20
# 49/49 [==============================] - 33s 680ms/step - loss: 9.2680e-09 - acc: 1.0000 - val_loss: 1.3702 - val_acc: 0.8816
# Epoch 17/20
# 49/49 [==============================] - 33s 672ms/step - loss: 6.8040e-09 - acc: 1.0000 - val_loss: 1.3903 - val_acc: 0.8815
# Epoch 18/20
# 49/49 [==============================] - 33s 672ms/step - loss: 5.3906e-09 - acc: 1.0000 - val_loss: 1.4063 - val_acc: 0.8816
# Epoch 19/20
# 49/49 [==============================] - 33s 669ms/step - loss: 4.4664e-09 - acc: 1.0000 - val_loss: 1.4209 - val_acc: 0.8816
# Epoch 20/20
# 49/49 [==============================] - 33s 672ms/step - loss: 3.8384e-09 - acc: 1.0000 - val_loss: 1.4320 - val_acc: 0.8818

# %% [markdown]
# 다음은 더 큰 네트워크가 기본 네트워크에 비해 얼마나 차이나는지를 보여줍니다. 점이 용량이 큰 네트워크의 검증 손실이고 덧셈 기호는 원본 네트워크의 검증 손실입니다.

# %%
hists = [org_hist, small_hist, big_hist]
titles = ['org','small','big']
colors = ['dodgerblue', 'orangered','green']
plot_lcurve(hists, titles, colors)

# %% [markdown]
# 용량이 큰 네트워크는 첫 번째 에포크 이후 거의 바로 과대적합이 시작되어 갈수록 더 심해집니다. 검증 손실도 매우 불안정합니다.
#
# 다음은 두 네트워크의 훈련 손실입니다:

# %% [markdown]
# 여기서 볼 수 있듯이 용량이 큰 네트워크는 훈련 손실이 매우 빠르게 0에 가까워집니다. 용량이 많은 네트워크일수록 더 빠르게 훈련 데이터를 모델링할 수 있습니다(결국 훈련 손실이 낮아집니다). 하지만 더욱 과대적합에 민감해집니다(결국 훈련과 검증 손실 사이에 큰 차이가 발생합니다).

# %% [markdown]
# ## 가중치 규제 추가
#
# 오캄의 면도날 이론을 알고 있을지 모르겠습니다. 어떤 것에 대한 두 가지의 설명이 있다면 더 적은 가정을 필요하는 간단한 설명이 옳을 것이라는 이론입니다. 이 개념은 신경망으로 학습되는 모델에도 적용됩니다. 어떤 훈련 데이터와 네트워크 구조가 주어졌을 때 데이터를 설명할 수 있는 가중치 값의 집합은 여러 개(여러 개의 모델)입니다. 간단한 모델이 복잡한 모델보다 덜 과대적합될 가능성이 높습니다.
#
# 여기에서 간단한 모델은 파라미터 값 분포의 엔트로피가 작은 모델입니다(또는 앞 절에서 본 것처럼 적은 수의 파라미터를 가진 모델입니다). 그러므로 과대적합을 완화시키기 위한 일반적인 방법은 네트워크의 복잡도에 제한을 두어 가중치가 작은 값을 가지도록 강제하는 것입니다. 가중치 값의 분포가 더 균일하게 됩니다. 이를 가중치 규제라고 하고 네트워크의 손실 함수에 큰 가중치에 연관된 비용을 추가합니다. 두 가지 형태의 비용이 있습니다.
#
# * L1 규제 : 가중치의 절대값에 비례하는 비용이 추가됩니다(가중치의 L1 노름).
# * L2 규제 : 가중치의 제곱에 비례하는 비용이 추가됩니다(가중치의 L2 노름). L2 규제는 신경망에서 가중치 감쇠라고도 부릅니다. 다른 이름 때문에 혼돈하지 마세요. 가중치 감쇠는 수학적으로 L2 규제와 동일합니다.
#
# 케라스에서 가중치 규제 인스턴스를 층의 키워드 매개변수로 전달하여 가중치 규제를 추가할 수 있습니다. 영화 리뷰 분류 네트워크에 L2 가중치 규제를 추가해 보죠:

# %%
# W 잘 조정하는 것
# W가 가질 수 있는 값 : -무한 ~ +무한 -> (실제론) 0을 기준으로 정규분포 따라 -1 ~ 1 사이에 많이 분포

# %% [markdown]
# `l2(0.001)`는 가중치 행렬의 모든 원소를 제곱하고 `0.001`을 곱하여 네트워크의 전체 손실에 더해진다는 의미입니다. 이 페널티 항은 훈련할 때만 추가됩니다. 이 네트워크의 손실은 테스트보다 훈련할 때 더 높을 것입니다.
#
# L2 규제 페널티의 효과를 확인해 보죠:

# %%
from tensorflow.keras import models, layers, utils, regularizers

def build_l2():
  x = layers.Input(shape = (10000))
  y = layers.Dense(16, activation = 'relu', kernel_regularizer=regularizers.l2(0.001))(x)
  y = layers.Dense(16, activation = 'relu', kernel_regularizer=regularizers.l2(0.001))(y)
  y = layers.Dense(1, activation = 'sigmoid')(y)
  return models.Model(x,y, name = 'L2')

l2 = build_l2()
l2.summary()
l2.compile(optimizer='rmsprop',
            loss='binary_crossentropy',
            metrics=['acc'])
# Out:
# Model: "L2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 10000)]           0
#
#  dense_33 (Dense)            (None, 16)                160016
#
#  dense_34 (Dense)            (None, 16)                272
#
#  dense_35 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
l2_hist = l2.fit(x_train, y_train,
                   epochs = 20, batch_size = 512,
                   validation_data = (x_test,y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 3s 54ms/step - loss: 0.5063 - acc: 0.8213 - val_loss: 0.3912 - val_acc: 0.8796
# Epoch 2/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.3258 - acc: 0.9027 - val_loss: 0.3562 - val_acc: 0.8765
# Epoch 3/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.2752 - acc: 0.9188 - val_loss: 0.3297 - val_acc: 0.8877
# Epoch 4/20
# 49/49 [==============================] - 2s 41ms/step - loss: 0.2544 - acc: 0.9273 - val_loss: 0.3311 - val_acc: 0.8875
# Epoch 5/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.2420 - acc: 0.9325 - val_loss: 0.3456 - val_acc: 0.8811
# Epoch 6/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.2302 - acc: 0.9380 - val_loss: 0.3470 - val_acc: 0.8832
# Epoch 7/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.2240 - acc: 0.9396 - val_loss: 0.3591 - val_acc: 0.8787
# Epoch 8/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.2177 - acc: 0.9425 - val_loss: 0.3603 - val_acc: 0.8802
# Epoch 9/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.2129 - acc: 0.9443 - val_loss: 0.3743 - val_acc: 0.8747
# Epoch 10/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.2103 - acc: 0.9442 - val_loss: 0.3928 - val_acc: 0.8696
# Epoch 11/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.2081 - acc: 0.9459 - val_loss: 0.3766 - val_acc: 0.8766
# Epoch 12/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.1997 - acc: 0.9489 - val_loss: 0.4123 - val_acc: 0.8657
# Epoch 13/20
# 49/49 [==============================] - 2s 41ms/step - loss: 0.1991 - acc: 0.9475 - val_loss: 0.3887 - val_acc: 0.8728
# Epoch 14/20
# 49/49 [==============================] - 2s 41ms/step - loss: 0.1966 - acc: 0.9488 - val_loss: 0.4036 - val_acc: 0.8697
# Epoch 15/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.1949 - acc: 0.9499 - val_loss: 0.3967 - val_acc: 0.8722
# Epoch 16/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.1904 - acc: 0.9525 - val_loss: 0.4377 - val_acc: 0.8636
# Epoch 17/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.1891 - acc: 0.9520 - val_loss: 0.4142 - val_acc: 0.8703
# Epoch 18/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.1848 - acc: 0.9546 - val_loss: 0.4294 - val_acc: 0.8643
# Epoch 19/20
# 49/49 [==============================] - 2s 50ms/step - loss: 0.1833 - acc: 0.9547 - val_loss: 0.4531 - val_acc: 0.8618
# Epoch 20/20
# 49/49 [==============================] - 2s 51ms/step - loss: 0.1784 - acc: 0.9574 - val_loss: 0.4188 - val_acc: 0.8699

# %% [markdown]
# 여기서 볼 수 있듯이 두 모델이 동일한 파라미터 수를 가지고 있더라도 L2 규제를 사용한 모델(점)이 기본 모델(덧셈 기호)보다 훨씬 더 과대적합에 잘 견디고 있습니다.
#
# 케라스에서 L2 규제 대신에 다음과 같은 가중치 규제 중 하나를 사용할 수 있습니다:

# %%
hists = [org_hist, small_hist, l2_hist]
titles = ['org','small','l2']
colors = ['dodgerblue', 'orangered','green']
plot_lcurve(hists, titles, colors)

# %% [markdown]
# ```python
# from keras import regularizers
#
# # L1 규제
# regularizers.l1(0.001)
#
# # L1과 L2 규제 병행
# regularizers.l1_l2(l1=0.001, l2=0.001)
# ```

# %% [markdown]
# ### l1(0.0001) 모델과 비교

# %%
from tensorflow.keras import models, layers, utils, regularizers

def build_l1():
  x = layers.Input(shape = (10000))
  y = layers.Dense(16, activation = 'relu', kernel_regularizer=regularizers.l1(0.001))(x)
  y = layers.Dense(16, activation = 'relu', kernel_regularizer=regularizers.l1(0.001))(y)
  y = layers.Dense(1, activation = 'sigmoid')(y)
  return models.Model(x,y, name = 'L1')

l1 = build_l1()
l1.summary()
l1.compile(optimizer='rmsprop',
            loss='binary_crossentropy',
            metrics=['acc'])
# Out:
# Model: "L1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_14 (InputLayer)       [(None, 10000)]           0
#
#  dense_39 (Dense)            (None, 16)                160016
#
#  dense_40 (Dense)            (None, 16)                272
#
#  dense_41 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
l1_hist = l1.fit(x_train, y_train,
                   epochs = 20, batch_size = 512,
                   validation_data = (x_test,y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 5s 84ms/step - loss: 0.9478 - acc: 0.7519 - val_loss: 0.6964 - val_acc: 0.8121
# Epoch 2/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.6439 - acc: 0.8440 - val_loss: 0.6119 - val_acc: 0.8518
# Epoch 3/20
# 49/49 [==============================] - 2s 44ms/step - loss: 0.5887 - acc: 0.8551 - val_loss: 0.5780 - val_acc: 0.8554
# Epoch 4/20
# 49/49 [==============================] - 2s 50ms/step - loss: 0.5624 - acc: 0.8591 - val_loss: 0.5671 - val_acc: 0.8564
# Epoch 5/20
# 49/49 [==============================] - 2s 49ms/step - loss: 0.5482 - acc: 0.8624 - val_loss: 0.5841 - val_acc: 0.8403
# Epoch 6/20
# 49/49 [==============================] - 3s 54ms/step - loss: 0.5354 - acc: 0.8674 - val_loss: 0.5317 - val_acc: 0.8649
# Epoch 7/20
# 49/49 [==============================] - 2s 50ms/step - loss: 0.5268 - acc: 0.8677 - val_loss: 0.5263 - val_acc: 0.8664
# Epoch 8/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.5188 - acc: 0.8706 - val_loss: 0.5319 - val_acc: 0.8616
# Epoch 9/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.5168 - acc: 0.8710 - val_loss: 0.5282 - val_acc: 0.8647
# Epoch 10/20
# 49/49 [==============================] - 2s 41ms/step - loss: 0.5133 - acc: 0.8722 - val_loss: 0.5161 - val_acc: 0.8700
# Epoch 11/20
# 49/49 [==============================] - 2s 41ms/step - loss: 0.5073 - acc: 0.8748 - val_loss: 0.5230 - val_acc: 0.8646
# Epoch 12/20
# 49/49 [==============================] - 2s 44ms/step - loss: 0.5032 - acc: 0.8770 - val_loss: 0.5077 - val_acc: 0.8732
# Epoch 13/20
# 49/49 [==============================] - 2s 49ms/step - loss: 0.5016 - acc: 0.8756 - val_loss: 0.5106 - val_acc: 0.8702
# Epoch 14/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.5005 - acc: 0.8756 - val_loss: 0.5005 - val_acc: 0.8757
# Epoch 15/20
# 49/49 [==============================] - 2s 45ms/step - loss: 0.4951 - acc: 0.8780 - val_loss: 0.5009 - val_acc: 0.8733
# Epoch 16/20
# 49/49 [==============================] - 3s 52ms/step - loss: 0.4913 - acc: 0.8784 - val_loss: 0.5076 - val_acc: 0.8709
# Epoch 17/20
# 49/49 [==============================] - 3s 62ms/step - loss: 0.4878 - acc: 0.8800 - val_loss: 0.5287 - val_acc: 0.8592
# Epoch 18/20
# 49/49 [==============================] - 3s 52ms/step - loss: 0.4857 - acc: 0.8789 - val_loss: 0.4997 - val_acc: 0.8741
# Epoch 19/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.4793 - acc: 0.8830 - val_loss: 0.4988 - val_acc: 0.8728
# Epoch 20/20
# 49/49 [==============================] - 2s 48ms/step - loss: 0.4739 - acc: 0.8860 - val_loss: 0.4914 - val_acc: 0.8748

# %%
hists = [org_hist, l1_hist, l2_hist]
titles = ['org','l1','l2']
colors = ['dodgerblue', 'orangered','green']
plot_lcurve(hists, titles, colors)

# %% [markdown]
# ### l1_l2(l1=0.0001, l2=0.0001)모델과 비교

# %%
from tensorflow.keras import models, layers, utils, regularizers

def build_l1_l2():
  x = layers.Input(shape = (10000))
  y = layers.Dense(16, activation = 'relu', kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001))(x)
  y = layers.Dense(16, activation = 'relu', kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001))(y)
  y = layers.Dense(1, activation = 'sigmoid')(y)
  return models.Model(x,y, name = 'L1_l2') # model 이름에 공백 x

l1_l2 = build_l1_l2()
l1_l2.summary()
l1_l2.compile(optimizer='rmsprop',
            loss='binary_crossentropy',
            metrics=['acc'])
# Out:
# Model: "L1_l2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_18 (InputLayer)       [(None, 10000)]           0
#
#  dense_51 (Dense)            (None, 16)                160016
#
#  dense_52 (Dense)            (None, 16)                272
#
#  dense_53 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
l1_l2_hist = l1_l2.fit(x_train, y_train,
                   epochs = 20, batch_size = 512,
                   validation_data = (x_test,y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 4s 58ms/step - loss: 0.9494 - acc: 0.7619 - val_loss: 0.6999 - val_acc: 0.8436
# Epoch 2/20
# 49/49 [==============================] - 3s 55ms/step - loss: 0.6573 - acc: 0.8442 - val_loss: 0.6220 - val_acc: 0.8564
# Epoch 3/20
# 49/49 [==============================] - 3s 58ms/step - loss: 0.6048 - acc: 0.8540 - val_loss: 0.5987 - val_acc: 0.8544
# Epoch 4/20
# 49/49 [==============================] - 3s 52ms/step - loss: 0.5766 - acc: 0.8603 - val_loss: 0.5639 - val_acc: 0.8626
# Epoch 5/20
# 49/49 [==============================] - 3s 58ms/step - loss: 0.5564 - acc: 0.8648 - val_loss: 0.5499 - val_acc: 0.8648
# Epoch 6/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.5431 - acc: 0.8671 - val_loss: 0.5402 - val_acc: 0.8658
# Epoch 7/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.5331 - acc: 0.8692 - val_loss: 0.5659 - val_acc: 0.8504
# Epoch 8/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.5227 - acc: 0.8730 - val_loss: 0.5561 - val_acc: 0.8513
# Epoch 9/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.5192 - acc: 0.8740 - val_loss: 0.5212 - val_acc: 0.8704
# Epoch 10/20
# 49/49 [==============================] - 3s 57ms/step - loss: 0.5131 - acc: 0.8770 - val_loss: 0.5278 - val_acc: 0.8657
# Epoch 11/20
# 49/49 [==============================] - 3s 53ms/step - loss: 0.5069 - acc: 0.8770 - val_loss: 0.5190 - val_acc: 0.8718
# Epoch 12/20
# 49/49 [==============================] - 3s 65ms/step - loss: 0.5001 - acc: 0.8817 - val_loss: 0.5122 - val_acc: 0.8712
# Epoch 13/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.4991 - acc: 0.8776 - val_loss: 0.5335 - val_acc: 0.8605
# Epoch 14/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.4925 - acc: 0.8823 - val_loss: 0.4974 - val_acc: 0.8753
# Epoch 15/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.4869 - acc: 0.8860 - val_loss: 0.5083 - val_acc: 0.8720
# Epoch 16/20
# 49/49 [==============================] - 3s 62ms/step - loss: 0.4850 - acc: 0.8828 - val_loss: 0.5250 - val_acc: 0.8619
# Epoch 17/20
# 49/49 [==============================] - 3s 56ms/step - loss: 0.4832 - acc: 0.8847 - val_loss: 0.5189 - val_acc: 0.8675
# Epoch 18/20
# 49/49 [==============================] - 2s 46ms/step - loss: 0.4762 - acc: 0.8896 - val_loss: 0.5204 - val_acc: 0.8632
# Epoch 19/20
# 49/49 [==============================] - 3s 58ms/step - loss: 0.4770 - acc: 0.8864 - val_loss: 0.5307 - val_acc: 0.8591
# Epoch 20/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.4719 - acc: 0.8883 - val_loss: 0.5058 - val_acc: 0.8712

# %%
hists = [org_hist, small_hist, l1_l2_hist]
titles = ['org','small','l1_l2']
colors = ['dodgerblue', 'orangered','green']
plot_lcurve(hists, titles, colors)

# %% [markdown]
# ## 드롭아웃 추가
#
# 드롭아웃은 토론토 대학의 제프리 힌튼과 그의 학생들이 개발했습니다. 신경망을 위해 사용되는 규제 기법 중에서 가장 효과적이고 널리 사용되는 방법 중에 하나입니다. 네트워크의 층에 드롭아웃을 적용하면 훈련하는 동안 무작위로 층의 일부 출력 특성을 제외시킵니다(0으로 만듭니다). 한 층이 정상적으로 훈련하는 동안에는 어떤 입력 샘플에 대해 `[0.2, 0.5, 1.3, 0.8, 1.1]` 벡터를 출력한다고 가정합시다. 드롭아웃을 적용하면 이 벡터의 일부가 무작위로 0으로 바뀝니다. 예를 들면 `[0, 0.5, 1.3, 0, 1.1]`이 됩니다. 드롭아웃 비율은 0이 될 특성의 비율입니다. 보통 0.2에서 0.5 사이로 지정됩니다. 테스트 단계에서는 어떤 유닛도 드롭아웃되지 않습니다. 대신에 층의 출력을 드롭아웃 비율에 비례하여 줄여 줍니다. 훈련할 때보다 더 많은 유닛이 활성화되기 때문입니다.
#
# 크기가 `(batch_size, features)`인 한 층의 출력을 담고 있는 넘파이 행렬을 생각해 보겠습니다. 훈련할 때는 이 행렬의 값의 일부가 랜덤하게 0이 됩니다:

# %% [markdown]
# ```python
# # 훈련할 때 유닛의 출력 중 50%를 버립니다
# layer_output *= np.random.randint(0, high=2, size=layer_output.shape)
# ```

# %% [markdown]
# 테스트할 때는 드롭아웃 비율로 출력을 낮추어 주어야 합니다. 여기에서는 0.5배만큼 스케일을 조정했습니다(앞에서 절반의 유닛을 드롭아웃했으므로):

# %% [markdown]
# ```python
# # 테스트 단계
# layer_output *= 0.5
# ```

# %% [markdown]
# 훈련 단계에 이 두 연산을 포함시켜 테스트 단계에는 출력을 그대로 두도록 구현할 수 있습니다. 실제로 종종 이런 방식으로 구현합니다:

# %% [markdown]
# ```python
# # 훈련 단계
# layer_output *= np.randint(0, high=2, size=layer_output.shape)
# # 여기에서 스케일을 낮추는 대신 높입니다![image.png](attachment:image.png)
# layer_output /= 0.5
# ```

# %% [markdown]
# 이 기법이 이상하고 무계획적으로 보일 수 있습니다. 왜 드롭아웃이 과대적합을 줄이는 데 도움이 될까요? 힌튼은 은행에서 사용하는 부정 방지 메커니즘에서 착안했다고 합니다. 그의 말을 빌리면 “은행에 갔을 때 행원들이 계속 바뀌길래 왜 그런지를 물었습니다. 자신들도 이유는 모르지만 자주 업무가 바뀐다고 했습니다. 나는 은행에서 부정 행위를 하려면 직원들 사이의 유대가 필요하기 때문이라고 판단했습니다. 각 샘플에 대해 뉴런의 일부를 무작위하게 제거하면 뉴런의 부정한 협업을 방지하고 결국 과대적합을 감소시킨다는 것을 깨달았습니다."
#
# 핵심 아이디어는 층의 출력 값에 노이즈를 추가하여 중요하지 않은 우연한 패턴(힌튼이 이야기한 부정한 협업)을 깨뜨리는 것입니다. 노이즈가 없다면 네트워크가 이 패턴을 기억하기 시작할 것입니다.
#
# 케라스에서는 층의 출력 바로 뒤에 `Dropout` 층을 추가하여 네트워크에 드롭아웃을 적용할 수 있습니다:

# %% [markdown]
# ```python
# model.add(layers.Dropout(0.5))
# ```

# %% [markdown]
# IMDB 네트워크에 두 개의 `Dropout` 층을 추가하고 과대적합을 얼마나 줄여주는지 확인해 보겠습니다:

# %%
from tensorflow.keras import models, layers, utils

def build_dropout():
  x = layers.Input(shape = (10000))
  y = layers.Dense(16, activation = 'relu')(x)
  y = layers.Dropout(0.5)(y)
  y = layers.Dense(16, activation = 'relu')(y)
  y = layers.Dropout(0.5)(y)
  y = layers.Dense(1, activation = 'sigmoid')(y)
  return models.Model(x,y, name = 'DropOut')

dropout = build_dropout()
dropout.summary()
dropout.compile(optimizer='rmsprop',
            loss='binary_crossentropy',
            metrics=['acc'])
# Out:
# Model: "DropOut"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, 10000)]           0
#
#  dense_57 (Dense)            (None, 16)                160016
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  dense_58 (Dense)            (None, 16)                272
#
#  dropout_3 (Dropout)         (None, 16)                0
#
#  dense_59 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
dropout_hist = dropout.fit(x_train, y_train,
                   epochs = 20, batch_size = 512,
                   validation_data = (x_test,y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 4s 53ms/step - loss: 0.6027 - acc: 0.6777 - val_loss: 0.4874 - val_acc: 0.8559
# Epoch 2/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.4525 - acc: 0.8116 - val_loss: 0.3534 - val_acc: 0.8815
# Epoch 3/20
# 49/49 [==============================] - 4s 77ms/step - loss: 0.3609 - acc: 0.8613 - val_loss: 0.3035 - val_acc: 0.8838
# Epoch 4/20
# 49/49 [==============================] - 2s 47ms/step - loss: 0.3017 - acc: 0.8897 - val_loss: 0.2766 - val_acc: 0.8904
# Epoch 5/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.2609 - acc: 0.9089 - val_loss: 0.2791 - val_acc: 0.8904
# Epoch 6/20
# 49/49 [==============================] - 2s 44ms/step - loss: 0.2314 - acc: 0.9213 - val_loss: 0.2987 - val_acc: 0.8852
# Epoch 7/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.2063 - acc: 0.9289 - val_loss: 0.3043 - val_acc: 0.8852
# Epoch 8/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.1920 - acc: 0.9344 - val_loss: 0.3155 - val_acc: 0.8845
# Epoch 9/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.1707 - acc: 0.9425 - val_loss: 0.3509 - val_acc: 0.8832
# Epoch 10/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.1607 - acc: 0.9450 - val_loss: 0.3693 - val_acc: 0.8816
# Epoch 11/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.1507 - acc: 0.9482 - val_loss: 0.4015 - val_acc: 0.8808
# Epoch 12/20
# 49/49 [==============================] - 2s 44ms/step - loss: 0.1404 - acc: 0.9503 - val_loss: 0.4123 - val_acc: 0.8808
# Epoch 13/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.1362 - acc: 0.9528 - val_loss: 0.4425 - val_acc: 0.8757
# Epoch 14/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.1295 - acc: 0.9548 - val_loss: 0.4290 - val_acc: 0.8767
# Epoch 15/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.1251 - acc: 0.9564 - val_loss: 0.4632 - val_acc: 0.8764
# Epoch 16/20
# 49/49 [==============================] - 2s 44ms/step - loss: 0.1217 - acc: 0.9558 - val_loss: 0.5008 - val_acc: 0.8772
# Epoch 17/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.1172 - acc: 0.9571 - val_loss: 0.5423 - val_acc: 0.8762
# Epoch 18/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.1187 - acc: 0.9588 - val_loss: 0.5359 - val_acc: 0.8748
# Epoch 19/20
# 49/49 [==============================] - 2s 42ms/step - loss: 0.1100 - acc: 0.9614 - val_loss: 0.5539 - val_acc: 0.8732
# Epoch 20/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.1084 - acc: 0.9599 - val_loss: 0.5775 - val_acc: 0.8726

# %% [markdown]
# 결과 그래프를 그려 보죠:

# %%
hists = [org_hist, small_hist, dropout_hist]
titles = ['org','small','dropout']
colors = ['dodgerblue', 'orangered','green']
plot_lcurve(hists, titles, colors)

# %% [markdown]
# 여기에서도 기본 네트워크보다 확실히 향상되었습니다.
#
# 정리하면 신경망에서 과대적합을 방지하기 위해 가장 널리 사용하는 방법은 다음과 같습니다.
#
# * 훈련 데이터를 더 모읍니다.
# * 네트워크의 용량을 감소시킵니다.
# * 가중치 규제를 추가합니다.
# * 드롭아웃을 추가합니다

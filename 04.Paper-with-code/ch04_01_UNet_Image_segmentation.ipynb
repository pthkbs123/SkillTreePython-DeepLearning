# %% [markdown]
# <a href="https://colab.research.google.com/github/pthkbs123/SkillTreePython-DeepLearning/blob/main/04.Paper-with-code/ch04_01_UNet_Image_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ch04.01 UNet-Image segmentation
#
# * 날짜: 2022-08-01
# * 이름: 박태현
#
# ## 학습내용
#     - Image segmentation에 대해 이해한다.
#     - UNet 모델에 대해 이해한다.
#     - 이미지 분절 작업을 수행한다.
#
# ## Image Segmentation
#
# ![](https://github.com/yebiny/Image-Segmentation-TF2/blob/main/imgs/seg_type.png?raw=true)
#
#
# ![](https://github.com/yebiny/Image-Segmentation-TF2/blob/main/imgs/seg_model.png?raw=true)

# %% [markdown]
# ## 모델: UNet
# ---
#
# ![]( https://github.com/yebiny/Image-Segmentation-TF2/blob/main/imgs/unet2.png?raw=true)

# %% [markdown]
# #### **레포지토리 임포트**
#
# https://github.com/karolzak/keras-unet
#
# ```
# ! git clone https://github.com/karolzak/keras-unet
# ```

# %%
! git clone https://github.com/karolzak/keras-unet
# Out:
# Cloning into 'keras-unet'...
# remote: Enumerating objects: 1234, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 1234 (delta 44), reused 75 (delta 34), pack-reused 1136
# Receiving objects: 100% (1234/1234), 31.94 MiB | 10.11 MiB/s, done.
# Resolving deltas: 100% (372/372), done.

# %%
import sys, os, glob
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import utils, callbacks
from keras_unet.models import custom_unet
from keras_unet.utils import plot_imgs
from PIL import Image

sys.path.append('/content/keras-unet')

# %% [markdown]
# #### **모델 생성**

# %%
from keras_unet.models import vanilla_unet

model = vanilla_unet(input_shape=(512, 512, 3))
# Out:
# -----------------------------------------
# keras-unet init: TF version is >= 2.0.0 - using `tf.keras` instead of `Keras`
# -----------------------------------------

# %%
utils.plot_model(model, show_shapes=True)

# %%
from keras_unet.models import custom_unet

model = custom_unet(
    input_shape=(512, 512, 3),
    use_batch_norm=False,
    num_classes=1,
    filters=64,
    dropout=0.2,
    output_activation='sigmoid')

utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ## 데이터셋: Whale-tails
# ---

# %% [markdown]
# ### **| 데이터 처리**

# %% [markdown]
# #### **데이터 경로 확보**

# %%
img_paths = glob.glob('/content/keras-unet/input/whales/*jpg')
mask_paths = glob.glob('/content/keras-unet/input/whales/*png')

print(len(img_paths), img_paths[0])
print(len(mask_paths), mask_paths[0])
# Out:
# 500 /content/keras-unet/input/whales/00d641885.jpg
# 148 /content/keras-unet/input/whales/00e4afee9.png

# %%
img_paths = [mask_path.replace('png', 'jpg') for mask_path in mask_paths]

print(len(img_paths), img_paths[0])
# Out:
# 148 /content/keras-unet/input/whales/00e4afee9.jpg

# %% [markdown]
# #### **넘파이 변환**

# %%
from PIL import Image
imgs = []
masks = []
for img_path, mask_path in zip(img_paths, mask_paths):
  # path2img
  img = Image.open(img_path).resize( (384,384) )
  img = np.array(img)

  # path2mask
  mask = Image.open(mask_path).resize( (384,384) )
  mask = np.array(mask)

  imgs.append(img)
  masks.append(mask)

imgs = np.asarray(imgs)
masks = np.asarray(masks)
masks = np.expand_dims(masks, 3)

imgs.shape, masks.shape
# Out:
# ((148, 384, 384, 3), (148, 384, 384, 1))

# %% [markdown]
# #### **데이터 확인**

# %%
from keras_unet.utils import plot_imgs

plot_imgs(imgs, masks, nm_img_to_plot = 3)

# %%
plt.subplot(121);_=plt.hist(imgs.flatten())
plt.subplot(122);_=plt.hist(masks.flatten())

# %%
mn, mx = np.min(imgs.flatten()), np.max(imgs.flatten())
print(f'인풋 이미지의 값 범위 : {mn}, {mx}')
print(f'마스크의 값 범위 : {set(masks.flatten())}') # 따로 전처리를 할 필요가 없다
# Out:
# 인풋 이미지의 값 범위 : 0, 255
# 마스크의 값 범위 : {0, 1}

# %% [markdown]
# #### **전처리**

# %%
def whale_preprocess(imgs, masks):
  imgs = imgs/255.0
  return imgs, masks

# %%
imgs_ds, masks_ds = whale_preprocess(imgs, masks)

mn, mx = np.min(imgs_ds.flatten()), np.max(imgs_ds.flatten())
print(f'인풋 이미지의 값 범위 : {mn}, {mx}')
print(f'마스크의 값 범위 : {set(masks_ds.flatten())}') 

plt.subplot(121);_=plt.hist(imgs.flatten())
plt.subplot(122);_=plt.hist(masks.flatten())
# Out:
# 인풋 이미지의 값 범위 : 0.0, 1.0
# 마스크의 값 범위 : {0, 1}

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(imgs_ds, masks_ds,
                                                    test_size = 0.1, random_state = 0)

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((133, 384, 384, 3), (15, 384, 384, 3), (133, 384, 384, 1), (15, 384, 384, 1))

# %% [markdown]
# #### **이미지 증강**

# %%
from keras_unet.utils import get_augmented

train_gen = get_augmented(x_train, y_train,
                          batch_size = 2, 
                          data_gen_args=dict(rotation_range=5.0, 
                                             height_shift_range=0.05, 
                                             width_shift_range=0.05,
                                             shear_range=40, 
                                             horizontal_flip=True, 
                                             vertical_flip=False, 
                                             fill_mode='constant')
                          )

# %%
samples = next(train_gen)
xs, ys = samples
print(xs.shape, ys.shape)
plot_imgs(xs, ys, nm_img_to_plot = 2)
# Out:
# (2, 384, 384, 3) (2, 384, 384, 1)

# %% [markdown]
# ### **| 모델 생성 및 학습**

# %% [markdown]
# #### **모델 생성**

# %%
model = custom_unet( (384,384,3),
                    filters = 32)

model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 384, 384, 3  0           []
#                                 )]
#
#  conv2d_57 (Conv2D)             (None, 384, 384, 32  864         ['input_4[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 384, 384, 32  128        ['conv2d_57[0][0]']
#  ormalization)                  )
#
#  spatial_dropout2d_10 (SpatialD  (None, 384, 384, 32  0          ['batch_normalization_18[0][0]']
#  ropout2D)                      )
#
#  conv2d_58 (Conv2D)             (None, 384, 384, 32  9216        ['spatial_dropout2d_10[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 384, 384, 32  128        ['conv2d_58[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_12 (MaxPooling2D  (None, 192, 192, 32  0          ['batch_normalization_19[0][0]']
#  )                              )
#
#  conv2d_59 (Conv2D)             (None, 192, 192, 64  18432       ['max_pooling2d_12[0][0]']
#                                 )
#
#  batch_normalization_20 (BatchN  (None, 192, 192, 64  256        ['conv2d_59[0][0]']
#  ormalization)                  )
#
#  spatial_dropout2d_11 (SpatialD  (None, 192, 192, 64  0          ['batch_normalization_20[0][0]']
#  ropout2D)                      )
#
#  conv2d_60 (Conv2D)             (None, 192, 192, 64  36864       ['spatial_dropout2d_11[0][0]']
#                                 )
#
#  batch_normalization_21 (BatchN  (None, 192, 192, 64  256        ['conv2d_60[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_13 (MaxPooling2D  (None, 96, 96, 64)  0           ['batch_normalization_21[0][0]']
#  )
#
#  conv2d_61 (Conv2D)             (None, 96, 96, 128)  73728       ['max_pooling2d_13[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 96, 96, 128)  512        ['conv2d_61[0][0]']
#  ormalization)
#
#  spatial_dropout2d_12 (SpatialD  (None, 96, 96, 128)  0          ['batch_normalization_22[0][0]']
#  ropout2D)
#
#  conv2d_62 (Conv2D)             (None, 96, 96, 128)  147456      ['spatial_dropout2d_12[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 96, 96, 128)  512        ['conv2d_62[0][0]']
#  ormalization)
#
#  max_pooling2d_14 (MaxPooling2D  (None, 48, 48, 128)  0          ['batch_normalization_23[0][0]']
#  )
#
#  conv2d_63 (Conv2D)             (None, 48, 48, 256)  294912      ['max_pooling2d_14[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 48, 48, 256)  1024       ['conv2d_63[0][0]']
#  ormalization)
#
#  spatial_dropout2d_13 (SpatialD  (None, 48, 48, 256)  0          ['batch_normalization_24[0][0]']
#  ropout2D)
#
#  conv2d_64 (Conv2D)             (None, 48, 48, 256)  589824      ['spatial_dropout2d_13[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 48, 48, 256)  1024       ['conv2d_64[0][0]']
#  ormalization)
#
#  max_pooling2d_15 (MaxPooling2D  (None, 24, 24, 256)  0          ['batch_normalization_25[0][0]']
#  )
#
#  conv2d_65 (Conv2D)             (None, 24, 24, 512)  1179648     ['max_pooling2d_15[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 24, 24, 512)  2048       ['conv2d_65[0][0]']
#  ormalization)
#
#  spatial_dropout2d_14 (SpatialD  (None, 24, 24, 512)  0          ['batch_normalization_26[0][0]']
#  ropout2D)
#
#  conv2d_66 (Conv2D)             (None, 24, 24, 512)  2359296     ['spatial_dropout2d_14[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 24, 24, 512)  2048       ['conv2d_66[0][0]']
#  ormalization)
#
#  conv2d_transpose_12 (Conv2DTra  (None, 48, 48, 256)  524544     ['batch_normalization_27[0][0]']
#  nspose)
#
#  concatenate_12 (Concatenate)   (None, 48, 48, 512)  0           ['conv2d_transpose_12[0][0]',
#                                                                   'batch_normalization_25[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 48, 48, 256)  1179648     ['concatenate_12[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 48, 48, 256)  1024       ['conv2d_67[0][0]']
#  ormalization)
#
#  conv2d_68 (Conv2D)             (None, 48, 48, 256)  589824      ['batch_normalization_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 48, 48, 256)  1024       ['conv2d_68[0][0]']
#  ormalization)
#
#  conv2d_transpose_13 (Conv2DTra  (None, 96, 96, 128)  131200     ['batch_normalization_29[0][0]']
#  nspose)
#
#  concatenate_13 (Concatenate)   (None, 96, 96, 256)  0           ['conv2d_transpose_13[0][0]',
#                                                                   'batch_normalization_23[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 96, 96, 128)  294912      ['concatenate_13[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 96, 96, 128)  512        ['conv2d_69[0][0]']
#  ormalization)
#
#  conv2d_70 (Conv2D)             (None, 96, 96, 128)  147456      ['batch_normalization_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 96, 96, 128)  512        ['conv2d_70[0][0]']
#  ormalization)
#
#  conv2d_transpose_14 (Conv2DTra  (None, 192, 192, 64  32832      ['batch_normalization_31[0][0]']
#  nspose)                        )
#
#  concatenate_14 (Concatenate)   (None, 192, 192, 12  0           ['conv2d_transpose_14[0][0]',
#                                 8)                                'batch_normalization_21[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 192, 192, 64  73728       ['concatenate_14[0][0]']
#                                 )
#
#  batch_normalization_32 (BatchN  (None, 192, 192, 64  256        ['conv2d_71[0][0]']
#  ormalization)                  )
#
#  conv2d_72 (Conv2D)             (None, 192, 192, 64  36864       ['batch_normalization_32[0][0]']
#                                 )
#
#  batch_normalization_33 (BatchN  (None, 192, 192, 64  256        ['conv2d_72[0][0]']
#  ormalization)                  )
#
#  conv2d_transpose_15 (Conv2DTra  (None, 384, 384, 32  8224       ['batch_normalization_33[0][0]']
#  nspose)                        )
#
#  concatenate_15 (Concatenate)   (None, 384, 384, 64  0           ['conv2d_transpose_15[0][0]',
#                                 )                                 'batch_normalization_19[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 384, 384, 32  18432       ['concatenate_15[0][0]']
#                                 )
#
#  batch_normalization_34 (BatchN  (None, 384, 384, 32  128        ['conv2d_73[0][0]']
#  ormalization)                  )
#
#  conv2d_74 (Conv2D)             (None, 384, 384, 32  9216        ['batch_normalization_34[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 384, 384, 32  128        ['conv2d_74[0][0]']
#  ormalization)                  )
#
#  conv2d_75 (Conv2D)             (None, 384, 384, 1)  33          ['batch_normalization_35[0][0]']
#
# ==================================================================================================
# Total params: 7,768,929
# Trainable params: 7,763,041
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %% [markdown]
# #### **컴파일 및 학습**

# %%
ckp = callbacks.ModelCheckpoint('unet_whale.h5',
                                monitor = 'val_loss',
                                save_best_only=True)

# %%
from keras_unet.metrics import iou

model.compile(optimizer = 'adam',
              loss = 'binary_crossentropy',
              metrics = [iou] ) # 케라스에서 iou함수 지원하지 않음

# %%
history = model.fit(train_gen,
                    epochs = 50,
                    steps_per_epoch=200,
                    validation_data = (x_test, y_test),
                    callbacks=[ckp])
# Out:
# Epoch 1/50
# 200/200 [==============================] - 30s 151ms/step - loss: 0.3401 - iou: 0.3133 - val_loss: 10.2322 - val_iou: 0.2118
# Epoch 2/50
# 200/200 [==============================] - 25s 127ms/step - loss: 0.2221 - iou: 0.4275 - val_loss: 0.2023 - val_iou: 0.5780
# Epoch 3/50
# 200/200 [==============================] - 25s 126ms/step - loss: 0.1896 - iou: 0.4821 - val_loss: 0.1422 - val_iou: 0.6162
# Epoch 4/50
# 200/200 [==============================] - 25s 123ms/step - loss: 0.1619 - iou: 0.5490 - val_loss: 0.1921 - val_iou: 0.5712
# Epoch 5/50
# 200/200 [==============================] - 24s 122ms/step - loss: 0.1457 - iou: 0.5723 - val_loss: 0.2497 - val_iou: 0.5180
# Epoch 6/50
# 200/200 [==============================] - 25s 126ms/step - loss: 0.1379 - iou: 0.6006 - val_loss: 0.4972 - val_iou: 0.3874
# Epoch 7/50
# 200/200 [==============================] - 25s 123ms/step - loss: 0.1226 - iou: 0.6322 - val_loss: 0.1072 - val_iou: 0.6981
# Epoch 8/50
# 200/200 [==============================] - 25s 123ms/step - loss: 0.1137 - iou: 0.6587 - val_loss: 0.0669 - val_iou: 0.7725
# Epoch 9/50
# 200/200 [==============================] - 25s 127ms/step - loss: 0.1051 - iou: 0.6818 - val_loss: 0.0639 - val_iou: 0.7820
# Epoch 10/50
# 200/200 [==============================] - 24s 121ms/step - loss: 0.0983 - iou: 0.7020 - val_loss: 0.0717 - val_iou: 0.7476
# Epoch 11/50
# 200/200 [==============================] - 24s 122ms/step - loss: 0.0937 - iou: 0.7096 - val_loss: 0.0677 - val_iou: 0.7986
# Epoch 12/50
# 200/200 [==============================] - 25s 126ms/step - loss: 0.0933 - iou: 0.7197 - val_loss: 0.0816 - val_iou: 0.7801
# Epoch 13/50
# 200/200 [==============================] - 24s 121ms/step - loss: 0.0896 - iou: 0.7251 - val_loss: 0.0842 - val_iou: 0.7838
# Epoch 14/50
# 200/200 [==============================] - 24s 122ms/step - loss: 0.0941 - iou: 0.7102 - val_loss: 0.0850 - val_iou: 0.7556
# Epoch 15/50
# 200/200 [==============================] - 25s 127ms/step - loss: 0.0779 - iou: 0.7538 - val_loss: 0.0666 - val_iou: 0.8055
# Epoch 16/50
# 200/200 [==============================] - 25s 123ms/step - loss: 0.0815 - iou: 0.7490 - val_loss: 0.0707 - val_iou: 0.8059
# Epoch 17/50
# 200/200 [==============================] - 25s 125ms/step - loss: 0.0751 - iou: 0.7621 - val_loss: 0.0608 - val_iou: 0.8197
# Epoch 18/50
# 200/200 [==============================] - 34s 168ms/step - loss: 0.0712 - iou: 0.7707 - val_loss: 0.0604 - val_iou: 0.8304
# Epoch 19/50
# 200/200 [==============================] - 33s 163ms/step - loss: 0.0669 - iou: 0.7867 - val_loss: 0.0805 - val_iou: 0.7865
# Epoch 20/50
# 200/200 [==============================] - 28s 142ms/step - loss: 0.0685 - iou: 0.7805 - val_loss: 0.0588 - val_iou: 0.8332
# Epoch 21/50
# 200/200 [==============================] - 33s 163ms/step - loss: 0.0671 - iou: 0.7880 - val_loss: 0.0577 - val_iou: 0.8154
# Epoch 22/50
# 200/200 [==============================] - 34s 170ms/step - loss: 0.0612 - iou: 0.7967 - val_loss: 0.0641 - val_iou: 0.8363
# Epoch 23/50
# 200/200 [==============================] - 30s 148ms/step - loss: 0.0630 - iou: 0.8011 - val_loss: 0.0843 - val_iou: 0.7572
# Epoch 24/50
# 200/200 [==============================] - 25s 127ms/step - loss: 0.0640 - iou: 0.7984 - val_loss: 0.0609 - val_iou: 0.8049
# Epoch 25/50
# 200/200 [==============================] - 25s 123ms/step - loss: 0.0521 - iou: 0.8281 - val_loss: 0.0761 - val_iou: 0.8166
# Epoch 26/50
# 200/200 [==============================] - 24s 121ms/step - loss: 0.0545 - iou: 0.8199 - val_loss: 0.0652 - val_iou: 0.8204
# Epoch 27/50
# 200/200 [==============================] - 27s 133ms/step - loss: 0.0646 - iou: 0.7926 - val_loss: 0.0545 - val_iou: 0.8441
# Epoch 28/50
# 200/200 [==============================] - 24s 122ms/step - loss: 0.0559 - iou: 0.8199 - val_loss: 0.0587 - val_iou: 0.8282
# Epoch 29/50
# 200/200 [==============================] - 24s 121ms/step - loss: 0.0523 - iou: 0.8275 - val_loss: 0.0558 - val_iou: 0.8255
# Epoch 30/50
# 200/200 [==============================] - 26s 128ms/step - loss: 0.0523 - iou: 0.8280 - val_loss: 0.0683 - val_iou: 0.8052
# Epoch 31/50
# 200/200 [==============================] - 24s 121ms/step - loss: 0.0499 - iou: 0.8325 - val_loss: 0.0575 - val_iou: 0.8469
# Epoch 32/50
# 200/200 [==============================] - 24s 122ms/step - loss: 0.0533 - iou: 0.8290 - val_loss: 0.0635 - val_iou: 0.8357
# Epoch 33/50
# 200/200 [==============================] - 25s 126ms/step - loss: 0.0459 - iou: 0.8433 - val_loss: 0.0754 - val_iou: 0.8291
# Epoch 34/50
# 200/200 [==============================] - 24s 121ms/step - loss: 0.0469 - iou: 0.8436 - val_loss: 0.0612 - val_iou: 0.8206
# Epoch 35/50
# 200/200 [==============================] - 24s 122ms/step - loss: 0.0467 - iou: 0.8430 - val_loss: 0.0585 - val_iou: 0.8468
# Epoch 36/50
# 200/200 [==============================] - 24s 122ms/step - loss: 0.0429 - iou: 0.8618 - val_loss: 0.0551 - val_iou: 0.8473
# Epoch 37/50
# 200/200 [==============================] - 25s 126ms/step - loss: 0.0427 - iou: 0.8544 - val_loss: 0.0585 - val_iou: 0.8320
# Epoch 38/50
# 200/200 [==============================] - 25s 123ms/step - loss: 0.0404 - iou: 0.8606 - val_loss: 0.0463 - val_iou: 0.8532
# Epoch 39/50
# 200/200 [==============================] - 24s 121ms/step - loss: 0.0501 - iou: 0.8343 - val_loss: 0.0602 - val_iou: 0.8369
# Epoch 40/50
# 200/200 [==============================] - 25s 126ms/step - loss: 0.0442 - iou: 0.8514 - val_loss: 0.0651 - val_iou: 0.8244
# Epoch 41/50
# 200/200 [==============================] - 24s 121ms/step - loss: 0.0422 - iou: 0.8585 - val_loss: 0.0698 - val_iou: 0.8350
# Epoch 42/50
# 200/200 [==============================] - 24s 119ms/step - loss: 0.0439 - iou: 0.8495 - val_loss: 0.0602 - val_iou: 0.8391
# Epoch 43/50
# 200/200 [==============================] - 24s 120ms/step - loss: 0.0425 - iou: 0.8587 - val_loss: 0.0472 - val_iou: 0.8680
# Epoch 44/50
# 200/200 [==============================] - 25s 124ms/step - loss: 0.0401 - iou: 0.8641 - val_loss: 0.0468 - val_iou: 0.8676
# Epoch 45/50
# 200/200 [==============================] - 24s 121ms/step - loss: 0.0435 - iou: 0.8585 - val_loss: 0.0606 - val_iou: 0.8471
# Epoch 46/50
# 200/200 [==============================] - 24s 121ms/step - loss: 0.0420 - iou: 0.8580 - val_loss: 0.0531 - val_iou: 0.8442
# Epoch 47/50
# 200/200 [==============================] - 25s 125ms/step - loss: 0.0369 - iou: 0.8737 - val_loss: 0.0592 - val_iou: 0.8392
# Epoch 48/50
# 200/200 [==============================] - 24s 120ms/step - loss: 0.0384 - iou: 0.8700 - val_loss: 0.0513 - val_iou: 0.8681
# Epoch 49/50
# 200/200 [==============================] - 24s 120ms/step - loss: 0.0370 - iou: 0.8720 - val_loss: 0.0574 - val_iou: 0.8556
# Epoch 50/50
# 200/200 [==============================] - 25s 124ms/step - loss: 0.0326 - iou: 0.8873 - val_loss: 0.0711 - val_iou: 0.8176

# %% [markdown]
# #### **Plot training history**

# %%
from keras_unet.utils import plot_segm_history

plot_segm_history(
    history, # required - keras training history object
    metrics=['iou', 'val_iou'], # optional - metrics names to plot
    losses=['loss', 'val_loss']) # optional - loss names to plot

# %% [markdown]
# #### **Plot original + ground truth + pred + overlay (pred on top of original)**

# %%
y_pred = model.predict(x_test)
print(y_test.shape, y_pred.shape)
# Out:
# (15, 384, 384, 1) (15, 384, 384, 1)

# %%
plot_imgs(org_imgs = x_test, mask_imgs = y_test,
          pred_imgs = y_pred,
          nm_img_to_plot=15)

# %% [markdown]
# ## 데이터셋: kz-isbi-challenge
# ---
#
# https://github.com/karolzak/keras-unet/blob/master/notebooks/kz-isbi-challenge.ipynb

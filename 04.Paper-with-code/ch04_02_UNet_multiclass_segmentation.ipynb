# %% [markdown]
# <a href="https://colab.research.google.com/github/pthkbs123/SkillTreePython-DeepLearning/blob/main/04.Paper-with-code/ch04_02_UNet_multiclass_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ch04.02 UNet-Image segmentation
#
# * 날짜: 2022-08-03
# * 이름: 박태현
#
# ## 학습내용
#     - Image multiclass segmentation에 대해 이해한다.
#     - 이미지 분절 작업을 수행한다.
#
# ## Muticlass Segmenation
#
#
#
# <p  align='center'>
# <img src ='https://miro.medium.com/max/1400/1*B16t8Do6hvuq2Q_2YOM-UQ.png' width=500>
# </p>
#
#
# <p  align='center'>
# <img src ='https://github.com/yebiny/SkillTreePython-DeepLearning/blob/main/imgs/ch0402-01.PNG?raw=true' width=800>
# </p>

# %%
! git clone https://github.com/karolzak/keras-unet
# Out:
# Cloning into 'keras-unet'...
# remote: Enumerating objects: 1234, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 1234 (delta 44), reused 75 (delta 34), pack-reused 1136
# Receiving objects: 100% (1234/1234), 31.94 MiB | 17.49 MiB/s, done.
# Resolving deltas: 100% (372/372), done.

# %%
import sys, os, glob
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
sys.path.append('/content/keras-unet')
from tensorflow.keras import utils, callbacks
from keras_unet.models import custom_unet
from keras_unet.utils import plot_imgs
from PIL import Image

# %%
from keras_unet.models import vanilla_unet

model = vanilla_unet(input_shape=(512, 512, 3))

# %%
from keras_unet.models import custom_unet

model = custom_unet(
    input_shape=(512, 512, 3),
    use_batch_norm=False,
    num_classes=1,
    filters=64,
    dropout=0.2,
    output_activation='sigmoid')

# utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ## 데이터셋: Crowd Instance-level Human Parsing (CIHP)
# ---
#
# (https://arxiv.org/abs/1811.12596)
#
# * 38,280개의 다양한 인간 이미지
# ![](https://github.com/yebiny/Image-Segmentation-TF2/blob/main/imgs/chip.png?raw=true)

# %%
# 데이터셋 불러오기
# !gdown https://drive.google.com/u/0/uc?id=10p_-JQ8T7EuOJ1AWLSQpkUcrIhtRJgK_&export=download
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=10p_-JQ8T7EuOJ1AWLSQpkUcrIhtRJgK_
# To: /content/instance-level-human-parsing.zip
# 100% 2.91G/2.91G [00:45<00:00, 64.4MB/s]

# %%
# !unzip -q instance-level-human-parsing.zip

# %% [markdown]
# ## 데이터 전처리

# %%
# 경로 확보

# Train / Validation / Test

data_dir = '/content/instance-level_human_parsing/instance-level_human_parsing/'
train_img_paths = sorted(glob.glob(f'{data_dir}/Training/Images/*'))
train_mask_paths = sorted(glob.glob(f'{data_dir}/Training/Category_ids/*'))

print(len(train_img_paths), train_img_paths[0])
print(len(train_mask_paths), train_mask_paths[0])
# Out:
# 28280 /content/instance-level_human_parsing/instance-level_human_parsing//Training/Images/0000006.jpg
# 28280 /content/instance-level_human_parsing/instance-level_human_parsing//Training/Category_ids/0000006.png

# %%
# 불러올 때 sorted로 정렬해도 되지만, 이 방법이 더 안전한 방법.
train_img_paths = [mask_path.replace('png', 'jpg') for mask_path in train_mask_paths]
train_img_paths = [img_path.replace('Category_ids', 'Images') for img_path in train_img_paths]


print(len(train_img_paths), train_img_paths[0])
print(len(train_mask_paths), train_mask_paths[0])
# Out:
# 28280 /content/instance-level_human_parsing/instance-level_human_parsing//Training/Images/0000006.jpg
# 28280 /content/instance-level_human_parsing/instance-level_human_parsing//Training/Category_ids/0000006.png

# %% [markdown]
# ## 첫 번째 이슈 : 넘파이 배열로 하기는 너무 큶

# %%
imgs = []
masks = []
for img_path, mask_path in zip(train_img_paths[:10], train_mask_paths[:10]):
  # path2img
  img = Image.open(img_path).resize( (128,128) )
  img = np.array(img)
  imgs.append(img)
  # path2mask
  mask = Image.open(mask_path).resize( (128,128) )
  mask = np.array(mask)
  masks.append(mask)
imgs = np.asarray(imgs)
masks = np.asarray(masks)
masks = np.expand_dims(masks, 3)

imgs.shape, masks.shape
# Out:
# ((10, 128, 128, 3), (10, 128, 128, 1))

# %%
# for 루프 대신 map 사용
# map에 들어갈 함수 특징 : 리스트가 아니라 scalar를 받는다.

def path2tensor(image_path, mask_path, IMAGE_SIZE=128): # 이미지 경로 한개, 마스크 경로 한개
  # 이미지 처리
  image = tf.io.read_file(image_path)
  image = tf.image.decode_png(image, channels=3)
  image.set_shape([None, None, 3])
  image = tf.image.resize(images=image, size=[IMAGE_SIZE, IMAGE_SIZE])
  image = image / 255.

  # 마스크 처리
  mask = tf.io.read_file(mask_path)
  mask = tf.image.decode_png(mask, channels=1)
  mask.set_shape([None, None, 1])
  mask = tf.image.resize(images=mask, size=[IMAGE_SIZE, IMAGE_SIZE])
  return image, mask

# %%
print(train_img_paths[1])
print(train_mask_paths[1])
# Out:
# /content/instance-level_human_parsing/instance-level_human_parsing//Training/Images/0000007.jpg
# /content/instance-level_human_parsing/instance-level_human_parsing//Training/Category_ids/0000007.png

# %%
img, mask = path2tensor(train_img_paths[2], train_mask_paths[2])
plt.imshow(img);plt.imshow(mask[:,:,0], alpha=.3, cmap='rainbow')
img.shape, mask.shape
# Out:
# (TensorShape([128, 128, 3]), TensorShape([128, 128, 1]))

# %%
train_ds = tf.data.Dataset.from_tensor_slices((train_img_paths, train_mask_paths))
train_ds = train_ds.map(path2tensor, num_parallel_calls=tf.data.AUTOTUNE)
train_ds = train_ds.batch(32, drop_remainder=True)
train_ds
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(32, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(32, 128, 128, 1), dtype=tf.float32, name=None))>

# %% [markdown]
# ## 두 번째 이슈 : 플로팅 다시

# %%
for imgs, masks in train_ds.take(1):
  print(imgs.shape, masks.shape)
  N = 10
  plt.subplot(121);_=plt.hist(tf.reshape(imgs, [-1]))
  plt.subplot(122);_=plt.hist(tf.reshape(masks, [-1]))
  plt.show()
  for img, mask in zip(imgs[:N], masks[:N]):
    plt.figure(figsize=(11,4))
    plt.subplot(131);plt.imshow(img);plt.xticks([]);plt.yticks([])
    plt.subplot(132);plt.imshow(img);plt.imshow(mask[:,:,0], alpha=.5, cmap='rainbow');plt.xticks([]);plt.yticks([])
    plt.subplot(133);plt.imshow(mask[:,:,0], cmap='rainbow');plt.xticks([]);plt.yticks([])
    plt.show()
# Out:
# (32, 128, 128, 3) (32, 128, 128, 1)

# %%
plt.subplot(121);_=plt.hist(imgs.flatten())
plt.subplot(122);_=plt.hist(masks.flatten())

# %% [markdown]
# ## 모델 준비
# ---

# %%
model = custom_unet( (128,128,3),
                    num_classes = 20,
                    filters = 32,
                    output_activation = 'softmax',
                    )
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_38 (Conv2D)             (None, 128, 128, 32  864         ['input_3[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 32  128        ['conv2d_38[0][0]']
#  alization)                     )
#
#  spatial_dropout2d_5 (SpatialDr  (None, 128, 128, 32  0          ['batch_normalization[0][0]']
#  opout2D)                       )
#
#  conv2d_39 (Conv2D)             (None, 128, 128, 32  9216        ['spatial_dropout2d_5[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 32  128        ['conv2d_39[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 64, 64, 32)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 64, 64, 64)   18432       ['max_pooling2d_8[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_40[0][0]']
#  rmalization)
#
#  spatial_dropout2d_6 (SpatialDr  (None, 64, 64, 64)  0           ['batch_normalization_2[0][0]']
#  opout2D)
#
#  conv2d_41 (Conv2D)             (None, 64, 64, 64)   36864       ['spatial_dropout2d_6[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_41[0][0]']
#  rmalization)
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 32, 32, 64)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 32, 32, 128)  73728       ['max_pooling2d_9[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 128)  512        ['conv2d_42[0][0]']
#  rmalization)
#
#  spatial_dropout2d_7 (SpatialDr  (None, 32, 32, 128)  0          ['batch_normalization_4[0][0]']
#  opout2D)
#
#  conv2d_43 (Conv2D)             (None, 32, 32, 128)  147456      ['spatial_dropout2d_7[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 128)  512        ['conv2d_43[0][0]']
#  rmalization)
#
#  max_pooling2d_10 (MaxPooling2D  (None, 16, 16, 128)  0          ['batch_normalization_5[0][0]']
#  )
#
#  conv2d_44 (Conv2D)             (None, 16, 16, 256)  294912      ['max_pooling2d_10[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 256)  1024       ['conv2d_44[0][0]']
#  rmalization)
#
#  spatial_dropout2d_8 (SpatialDr  (None, 16, 16, 256)  0          ['batch_normalization_6[0][0]']
#  opout2D)
#
#  conv2d_45 (Conv2D)             (None, 16, 16, 256)  589824      ['spatial_dropout2d_8[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 16, 16, 256)  1024       ['conv2d_45[0][0]']
#  rmalization)
#
#  max_pooling2d_11 (MaxPooling2D  (None, 8, 8, 256)   0           ['batch_normalization_7[0][0]']
#  )
#
#  conv2d_46 (Conv2D)             (None, 8, 8, 512)    1179648     ['max_pooling2d_11[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 8, 8, 512)   2048        ['conv2d_46[0][0]']
#  rmalization)
#
#  spatial_dropout2d_9 (SpatialDr  (None, 8, 8, 512)   0           ['batch_normalization_8[0][0]']
#  opout2D)
#
#  conv2d_47 (Conv2D)             (None, 8, 8, 512)    2359296     ['spatial_dropout2d_9[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 8, 8, 512)   2048        ['conv2d_47[0][0]']
#  rmalization)
#
#  conv2d_transpose_8 (Conv2DTran  (None, 16, 16, 256)  524544     ['batch_normalization_9[0][0]']
#  spose)
#
#  concatenate_8 (Concatenate)    (None, 16, 16, 512)  0           ['conv2d_transpose_8[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 16, 16, 256)  1179648     ['concatenate_8[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_48[0][0]']
#  ormalization)
#
#  conv2d_49 (Conv2D)             (None, 16, 16, 256)  589824      ['batch_normalization_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_49[0][0]']
#  ormalization)
#
#  conv2d_transpose_9 (Conv2DTran  (None, 32, 32, 128)  131200     ['batch_normalization_11[0][0]']
#  spose)
#
#  concatenate_9 (Concatenate)    (None, 32, 32, 256)  0           ['conv2d_transpose_9[0][0]',
#                                                                   'batch_normalization_5[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 32, 32, 128)  294912      ['concatenate_9[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 128)  512        ['conv2d_50[0][0]']
#  ormalization)
#
#  conv2d_51 (Conv2D)             (None, 32, 32, 128)  147456      ['batch_normalization_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 128)  512        ['conv2d_51[0][0]']
#  ormalization)
#
#  conv2d_transpose_10 (Conv2DTra  (None, 64, 64, 64)  32832       ['batch_normalization_13[0][0]']
#  nspose)
#
#  concatenate_10 (Concatenate)   (None, 64, 64, 128)  0           ['conv2d_transpose_10[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 64, 64, 64)   73728       ['concatenate_10[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 64, 64, 64)  256         ['conv2d_52[0][0]']
#  ormalization)
#
#  conv2d_53 (Conv2D)             (None, 64, 64, 64)   36864       ['batch_normalization_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 64)  256         ['conv2d_53[0][0]']
#  ormalization)
#
#  conv2d_transpose_11 (Conv2DTra  (None, 128, 128, 32  8224       ['batch_normalization_15[0][0]']
#  nspose)                        )
#
#  concatenate_11 (Concatenate)   (None, 128, 128, 64  0           ['conv2d_transpose_11[0][0]',
#                                 )                                 'batch_normalization_1[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 128, 128, 32  18432       ['concatenate_11[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 128, 128, 32  128        ['conv2d_54[0][0]']
#  ormalization)                  )
#
#  conv2d_55 (Conv2D)             (None, 128, 128, 32  9216        ['batch_normalization_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 128, 128, 32  128        ['conv2d_55[0][0]']
#  ormalization)                  )
#
#  conv2d_56 (Conv2D)             (None, 128, 128, 20  660         ['batch_normalization_17[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 7,769,556
# Trainable params: 7,763,668
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %%
# 이미지 증강
# validation / test

# %% [markdown]
# ## 결과 확인

# %%
for imgs, masks in train_ds.take(1):
  N = 5
  preds = model.predict(imgs)
  preds = tf.argmax(preds, 3)
  print(masks.shape, preds.shape)
  for img, mask, pred in zip(imgs[:N], masks[:N], preds[:N]):
    plt.figure(figsize=(11,4))
    plt.subplot(141);plt.imshow(img);plt.xticks([]);plt.yticks([])
    plt.subplot(142);plt.imshow(img);plt.imshow(pred, alpha=.5, cmap='rainbow');plt.xticks([]);plt.yticks([])
    plt.subplot(143);plt.imshow(pred, cmap='rainbow');plt.xticks([]);plt.yticks([])
    plt.subplot(144);plt.imshow(mask[:,:,0], cmap='rainbow');plt.xticks([]);plt.yticks([])
    plt.show()
# Out:
# (32, 128, 128, 1) (32, 128, 128)
